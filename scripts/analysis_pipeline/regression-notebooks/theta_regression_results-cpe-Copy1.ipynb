# %% [markdown]
# # SWB Regression Pipeline - Theta CPE Only Models
# Created: 09/30/2024 \
# Updated: 10/01/2024 \
# *ran with 1 sec regression dfs from 09/25/2024*

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp, pearsonr, spearmanr
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import re
import datetime
import scipy
import random
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.regression.mixed_linear_model import MixedLM 
from joblib import Parallel, delayed
import pickle
import itertools
import time 
from matplotlib.ticker import StrMethodFormatter
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
import matplotlib as mpl
from matplotlib import cm
import patsy
from statsmodels.api import OLS
from scipy import stats
from tqdm import tqdm
# from sklearn.linear_model import RANSACRegressor
# from sklearn.metrics import r2_score, mean_squared_error



import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Specify root directory for un-archived data and results 
base_dir   = '/sc/arion/projects/guLab/Alie/SWB/ephys_analysis/'
anat_dir   = f'{base_dir}recon_labels/'
neural_dir = f'{base_dir}data/'
save_dir   = f'{base_dir}results/bandpow_encoding_models/'
fig_dir    = f'{base_dir}figs/bandpow_regressions/'
script_dir = '/hpc/users/finka03/swb_ephys_analysis/scripts/'

date = datetime.date.today().strftime('%m%d%Y')
print(date)
# Out:
# 10012024

# %%
import sys
sys.path.append(f'{base_dir}LFPAnalysis/')

from LFPAnalysis import analysis_utils

sys.path.append(f'{script_dir}analysis_notebooks/')

from ieeg_tools import *
from plot_tools import *

# %%
subj_ids = list(pd.read_excel(f'{base_dir}/subj_info/SWB_subjects.xlsx', sheet_name='Usable_Subjects', usecols=[0]).PatientID)
n_subj = len(subj_ids)
# subj_ids

# %% [markdown]
# # Load beta power data

# %%
epoch_len = '1sec'

# %%
band = 'theta' 
theta_df = pd.read_csv(f'{save_dir}regression_dfs/{band}_master_df_{epoch_len}.csv')
theta_df.subj_id.unique()
# Out:
# array(['MS002', 'MS003', 'MS009', 'MS011', 'MS015', 'MS016', 'MS017',
#        'MS019', 'MS022', 'MS024', 'MS025', 'MS026', 'MS027', 'MS028',
#        'MS029', 'MS030', 'MS033', 'MS035', 'MS041', 'MS043', 'MS048',
#        'MS050', 'DA8', 'DA023', 'DA026', 'DA037', 'DA039'], dtype=object)

# %%
roi_reref_labels_master_df = pd.read_csv(
    glob(f'{base_dir}results/roi_info/roi_reref_labels_master.csv')[0])
roi_reref_labels_master_df = roi_reref_labels_master_df.drop(columns=['Unnamed: 0'])

# %%
roi_reref_labels_master_df.roi.value_counts()
# Out:
# roi
# dmpfc            225
# ofc              202
# acc              193
# sts              155
# hpc              135
# amy              113
# dlpfc            107
# temporal         105
# vlpfc             82
# ains              71
# pins              60
# thalamus          58
# temporal pole     31
# mcc               28
# phg               25
# motor             25
# parietal          24
# vmpfc             23
# caudate            8
# pcc                1
# Name: count, dtype: int64

# %%
# keep_rois = roi_reref_labels_master_df.roi.value_counts().index[
#     roi_reref_labels_master_df.roi.value_counts().values>=50].tolist()

keep_rois = ['dlpfc','vlpfc','dmpfc','ofc','ains','pins','acc','amy','hpc']     
keep_rois
# Out:
# ['dlpfc', 'vlpfc', 'dmpfc', 'ofc', 'ains', 'pins', 'acc', 'amy', 'hpc']

# %%
# ####### NEW DATA FRAME 
theta_reg_df = theta_df.copy()
theta_reg_df = theta_reg_df[theta_reg_df.roi.isin(keep_rois)]

# %% [markdown]
# # Test Single Electrode Regressions

# %%
elec_col    = 'unique_reref_ch'
main_var    = 'cpe'
# reg_formula = 'band_pow~GambleChoice+TotalProfit+cpe'
reg_formula = 'band_pow~GambleChoice+TrialEV+cpe'

n_permutations = 1000
results_dict, main_var_sig = run_individual_elec_regression(theta_reg_df,reg_formula,elec_col, main_var,n_permutations)
# Out:
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2709.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2901.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2893.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.33it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2890.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2892.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2911.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.01it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2465.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2877.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2892.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.39it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2913.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.92it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2876.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.53it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.85it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.62it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2907.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2883.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.92it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.83it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.01it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.60it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.60it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.07it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2961.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2958.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2964.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2963.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2972.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2965.92it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2962.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2967.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2963.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2964.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2967.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2970.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.83it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2963.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2972.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2854.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2962.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2975.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2958.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2964.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2967.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2967.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2971.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2966.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2971.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2978.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2968.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2968.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2968.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2982.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2975.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2977.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2964.07it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2972.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2972.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2902.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.62it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.33it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.85it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.01it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.39it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.60it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.92it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.54it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3034.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3025.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3036.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3035.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3023.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3046.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3041.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3025.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3050.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3045.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3043.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3028.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3033.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3034.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3040.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3040.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3027.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3037.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3030.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3034.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3026.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3046.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3027.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3029.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3036.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3040.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3036.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3017.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3015.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3032.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3021.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3031.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3023.83it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3025.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3023.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3020.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2985.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3019.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3015.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3012.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3018.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3008.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3024.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3023.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3006.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3021.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3020.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3024.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3018.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3027.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3023.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3021.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3027.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3021.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3020.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3014.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3033.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3029.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3022.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 3020.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.54it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.54it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.01it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.06it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.53it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2964.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2975.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2970.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2972.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2976.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2983.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2970.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2973.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2979.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.85it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.66it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.59it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.01it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2897.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.60it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.53it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.06it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.31it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2961.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2958.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2958.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.83it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.22it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.58it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.62it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.08it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.33it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.85it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2837.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.80it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.16it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2911.60it/s]
# ...
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2961.73it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2962.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2951.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2959.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2954.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.72it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.75it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.39it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.99it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.94it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.68it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.28it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.07it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.24it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.74it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.50it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.57it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2801.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2935.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.85it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2940.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.55it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.29it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.53it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.27it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2914.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2910.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2910.63it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2889.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.84it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.90it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.56it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.05it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.52it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.45it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.17it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.70it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.54it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.33it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.07it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.34it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.62it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.00it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2909.23it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2909.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.02it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.49it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.30it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.83it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2911.96it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2922.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2916.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.65it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2894.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.97it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.15it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.89it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.67it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.14it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2930.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2927.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2917.88it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2921.95it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.76it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2915.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.53it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2920.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2912.64it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2925.42it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2924.60it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2923.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2926.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2918.81it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2919.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2929.44it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2950.20it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2961.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2955.37it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2963.98it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2961.41it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.87it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.36it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.47it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.35it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.04it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.86it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2928.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2941.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.43it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.19it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2962.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2957.48it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.54it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2949.13it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.46it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.69it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2960.25it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2931.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2956.93it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2952.40it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2953.78it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.03it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2937.38it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.26it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.51it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2947.06it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.32it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2936.18it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.21it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2939.11it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2934.82it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2933.09it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2944.71it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2948.91it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2943.61it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2932.10it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2938.77it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2942.12it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2945.79it/s]
# Permutations: 100%|██████████| 1000/1000 [00:00<00:00, 2946.90it/s]

# %%
save_vars = results_dict['MS002_lacas1-lacas2'].index.tolist()
save_vars
# Out:
# ['Intercept', 'GambleChoice[T.safe]', 'TrialEV', 'cpe']

# %%
results = single_elec_permutation_results(results_dict,theta_reg_df,save_vars)
results
# Out:
#            unique_elec_id subj_id    roi  bdi  Original_Estimate_Intercept  \
# 0     MS002_lacas1-lacas2   MS002    acc   14                     0.178282
# 1     MS002_lacas2-lacas3   MS002    acc   14                     0.033429
# 2     MS002_lacas3-lacas4   MS002    acc   14                     0.100253
# 3     MS002_lacas4-lacas5   MS002    acc   14                     0.075507
# 4     MS002_lacas5-lacas6   MS002    acc   14                     0.151994
# ...                   ...     ...    ...  ...                          ...
# 1183  DA039_rpins1-rpins2   DA039   pins   22                     0.145607
# 1184  DA039_rpins2-rpins3   DA039   pins   22                    -0.051109
# 1185  DA039_rpins3-rpins4   DA039   pins   22                    -0.009005
# 1186  DA039_rsgcc6-rsgcc7   DA039  vlpfc   22                    -0.113534
# 1187  DA039_rsgcc7-rsgcc8   DA039  vlpfc   22                    -0.130577
#
#       Original_Estimate_GambleChoice[T.safe]  Original_Estimate_TrialEV  \
# 0                                  -0.120838                  -0.013575
# 1                                   0.089781                  -0.007261
# 2                                   0.026099                  -0.128263
# 3                                   0.031335                   0.141511
# 4                                   0.041456                   0.043684
# ...                                      ...                        ...
# 1183                               -0.003699                   0.050519
# 1184                                0.168455                   0.216447
# 1185                                0.020496                  -0.037638
# 1186                                0.116915                  -0.037591
# 1187                                0.122897                  -0.030435
#
#       Original_Estimate_cpe  Permuted_Mean_Intercept  \
# 0                  0.021376                 0.097131
# 1                  0.075003                 0.094042
# 2                 -0.041046                 0.117813
# 3                  0.010082                 0.094090
# 4                  0.009587                 0.179991
# ...                     ...                      ...
# 1183              -0.077619                 0.146065
# 1184               0.024138                 0.029335
# 1185              -0.009052                -0.002958
# 1186              -0.030265                -0.070129
# 1187              -0.057711                -0.083286
#
#       Permuted_Mean_GambleChoice[T.safe]  ...  Permuted_Std_TrialEV  \
# 0                              -0.004052  ...              0.077590
# 1                               0.001884  ...              0.090375
# 2                               0.000461  ...              0.077884
# 3                               0.005164  ...              0.084325
# 4                               0.001279  ...              0.087375
# ...                                  ...  ...                   ...
# 1183                           -0.001180  ...              0.097272
# 1184                           -0.003586  ...              0.082714
# 1185                            0.000308  ...              0.077975
# 1186                            0.001539  ...              0.077839
# 1187                           -0.001552  ...              0.080610
#
#       Permuted_Std_cpe  Z_Score_Intercept  Z_Score_GambleChoice[T.safe]  \
# 0             0.072540           1.406608                     -1.406213
# 1             0.089460          -0.920478                      0.927175
# 2             0.073809          -0.319645                      0.324181
# 3             0.084097          -0.299262                      0.292652
# 4             0.083905          -0.430522                      0.429104
# ...                ...                ...                           ...
# 1183          0.082926          -0.010504                     -0.024482
# 1184          0.070630          -2.307096                      2.104300
# 1185          0.067288          -0.182097                      0.258855
# 1186          0.063453          -1.300185                      1.474078
# 1187          0.066899          -1.337451                      1.494898
#
#       Z_Score_TrialEV  Z_Score_cpe  P_Value_Intercept  \
# 0           -0.118804     0.251827           0.159544
# 1           -0.061210     0.867800           0.357323
# 2           -1.616289    -0.578933           0.749237
# 3            1.646505     0.119455           0.764740
# 4            0.535529     0.101200           0.666816
# ...               ...          ...                ...
# 1183         0.482231    -0.910267           0.991619
# 1184         2.677562     0.315481           0.021049
# 1185        -0.463293    -0.121523           0.855506
# 1186        -0.531597    -0.485730           0.193537
# 1187        -0.372668    -0.827909           0.181075
#
#       P_Value_GambleChoice[T.safe]  P_Value_TrialEV  P_Value_cpe
# 0                         0.159661         0.905431     0.801174
# 1                         0.353836         0.951192     0.385504
# 2                         0.745801         0.106032     0.562635
# 3                         0.769788         0.099660     0.904915
# 4                         0.667848         0.592284     0.919391
# ...                            ...              ...          ...
# 1183                      0.980468         0.629642     0.362682
# 1184                      0.035352         0.007416     0.752396
# 1185                      0.795747         0.643154     0.903277
# 1186                      0.140461         0.595005     0.627158
# 1187                      0.134941         0.709395     0.407722
#
# [1188 rows x 24 columns]

# %% [markdown]
# ### Save results as pickle file

# %%
save_path = f'{save_dir}/{band}/'
os.makedirs(save_path, exist_ok=True)

fname = f'{save_path}{band}_perm_regression_results_cpe-only_model_{date}.pkl'
pickle.dump(results, open(fname,"wb"))

# %%
sig_data = results[results.P_Value_cpe < 0.05]
sig_data
# Out:
#              unique_elec_id subj_id    roi  bdi  Original_Estimate_Intercept  \
# 22      MS002_lhplt1-lhplt2   MS002    hpc   14                    -0.052925
# 26      MS002_lloif1-lloif2   MS002    ofc   14                     0.295279
# 36    MS002_lmoif11-lmoif12   MS002  vlpfc   14                     0.005906
# 48      MS002_racas1-racas2   MS002    acc   14                    -0.020995
# 51      MS002_racas6-racas7   MS002  dmpfc   14                     0.074063
# ...                     ...     ...    ...  ...                          ...
# 1159    DA039_rains3-rains4   DA039   ains   22                    -0.111105
# 1160    DA039_rains4-rains5   DA039   ains   22                    -0.052222
# 1172        DA039_rof1-rof2   DA039    ofc   22                    -0.117639
# 1179        DA039_rof8-rof9   DA039  dlpfc   22                     0.036923
# 1181      DA039_rof10-rof11   DA039  dlpfc   22                    -0.088210
#
#       Original_Estimate_GambleChoice[T.safe]  Original_Estimate_TrialEV  \
# 22                                  0.200351                   0.117224
# 26                                 -0.070832                   0.073507
# 36                                 -0.006091                  -0.026910
# 48                                  0.037034                   0.121036
# 51                                  0.128051                  -0.045131
# ...                                      ...                        ...
# 1159                                0.175318                   0.016879
# 1160                                0.041772                   0.084228
# 1172                                0.115311                  -0.032195
# 1179                                0.009339                   0.229387
# 1181                                0.130831                   0.146534
#
#       Original_Estimate_cpe  Permuted_Mean_Intercept  \
# 22                 0.212338                 0.082933
# 26                 0.195384                 0.246848
# 36                 0.149162                -0.000170
# 48                 0.167889                 0.004520
# 51                 0.223395                 0.165521
# ...                     ...                      ...
# 1159              -0.199505                -0.044749
# 1160              -0.158460                -0.032785
# 1172              -0.165554                -0.074629
# 1179               0.131823                 0.055251
# 1181              -0.149438                -0.029546
#
#       Permuted_Mean_GambleChoice[T.safe]  ...  Permuted_Std_TrialEV  \
# 22                              0.003689  ...              0.085558
# 26                             -0.001968  ...              0.091638
# 36                              0.001558  ...              0.065329
# 48                             -0.000231  ...              0.065832
# 51                             -0.005469  ...              0.091113
# ...                                  ...  ...                   ...
# 1159                            0.004712  ...              0.094468
# 1160                           -0.001028  ...              0.089241
# 1172                           -0.002326  ...              0.075804
# 1179                           -0.001841  ...              0.079565
# 1181                           -0.002151  ...              0.082018
#
#       Permuted_Std_cpe  Z_Score_Intercept  Z_Score_GambleChoice[T.safe]  \
# 22            0.077813          -2.141218                      2.152454
# 26            0.091722           0.715586                     -0.706783
# 36            0.062227           0.121919                     -0.106610
# 48            0.064164          -0.509983                      0.517293
# 51            0.085866          -1.390868                      1.409977
# ...                ...                ...                           ...
# 1159          0.079496          -1.624959                      1.775473
# 1160          0.074857          -0.492619                      0.460794
# 1172          0.062278          -1.293099                      1.502204
# 1179          0.065668          -0.529944                      0.137563
# 1181          0.068434          -1.698559                      1.643964
#
#       Z_Score_TrialEV  Z_Score_cpe  P_Value_Intercept  \
# 22           1.350678     2.769782           0.032256
# 26           0.796501     2.119625           0.474247
# 36          -0.393552     2.375489           0.902963
# 48           1.869095     2.569769           0.610063
# 51          -0.497483     2.617812           0.164265
# ...               ...          ...                ...
# 1159         0.189430    -2.453851           0.104171
# 1160         0.956609    -2.118620           0.622282
# 1172        -0.437340    -2.602981           0.195977
# 1179         2.906786     2.045026           0.596151
# 1181         1.775225    -2.165602           0.089402
#
#       P_Value_GambleChoice[T.safe]  P_Value_TrialEV  P_Value_cpe
# 22                        0.031362         0.176799     0.005609
# 26                        0.479701         0.425741     0.034038
# 36                        0.915098         0.693912     0.017526
# 48                        0.604952         0.061610     0.010177
# 51                        0.158546         0.618849     0.008850
# ...                            ...              ...          ...
# 1159                      0.075820         0.849756     0.014134
# 1160                      0.644946         0.338765     0.034123
# 1172                      0.133045         0.661865     0.009242
# 1179                      0.890586         0.003652     0.040852
# 1181                      0.100184         0.075861     0.030342
#
# [85 rows x 24 columns]

# %%
sig_data.roi.value_counts()
# Out:
# roi
# acc      16
# dmpfc    14
# ofc      14
# hpc      11
# dlpfc    10
# ains      8
# pins      5
# vlpfc     4
# amy       3
# Name: count, dtype: int64

# %%
sig_data.roi.unique()
# Out:
# array(['hpc', 'ofc', 'vlpfc', 'acc', 'dmpfc', 'ains', 'pins', 'dlpfc',
#        'amy'], dtype=object)

# %% [markdown]
# ### ROI Significance Testing
# - % of sig elecs in ROI (also split by BDI)
# - binomial test for whether sig proportion of elecs in ROI
# - ttests from zero

# %%
# add mask col for sig cpe elecs 
results['cpe_sig']   = results['P_Value_cpe'].apply(lambda x: 0 if x > 0.05 else 1)
results['bdi_split'] = results['bdi'].apply(lambda x: 0 if x < 20 else 1)

results.head()

# results.to_csv(f'{save_path}{band}_perm_regression_results_df_{epoch_len}.csv')
# Out:
#         unique_elec_id subj_id  roi  bdi  Original_Estimate_Intercept  \
# 0  MS002_lacas1-lacas2   MS002  acc   14                     0.178282
# 1  MS002_lacas2-lacas3   MS002  acc   14                     0.033429
# 2  MS002_lacas3-lacas4   MS002  acc   14                     0.100253
# 3  MS002_lacas4-lacas5   MS002  acc   14                     0.075507
# 4  MS002_lacas5-lacas6   MS002  acc   14                     0.151994
#
#    Original_Estimate_GambleChoice[T.safe]  Original_Estimate_TrialEV  \
# 0                               -0.120838                  -0.013575
# 1                                0.089781                  -0.007261
# 2                                0.026099                  -0.128263
# 3                                0.031335                   0.141511
# 4                                0.041456                   0.043684
#
#    Original_Estimate_cpe  Permuted_Mean_Intercept  \
# 0               0.021376                 0.097131
# 1               0.075003                 0.094042
# 2              -0.041046                 0.117813
# 3               0.010082                 0.094090
# 4               0.009587                 0.179991
#
#    Permuted_Mean_GambleChoice[T.safe]  ...  Z_Score_Intercept  \
# 0                           -0.004052  ...           1.406608
# 1                            0.001884  ...          -0.920478
# 2                            0.000461  ...          -0.319645
# 3                            0.005164  ...          -0.299262
# 4                            0.001279  ...          -0.430522
#
#    Z_Score_GambleChoice[T.safe]  Z_Score_TrialEV  Z_Score_cpe  \
# 0                     -1.406213        -0.118804     0.251827
# 1                      0.927175        -0.061210     0.867800
# 2                      0.324181        -1.616289    -0.578933
# 3                      0.292652         1.646505     0.119455
# 4                      0.429104         0.535529     0.101200
#
#    P_Value_Intercept  P_Value_GambleChoice[T.safe]  P_Value_TrialEV  \
# 0           0.159544                      0.159661         0.905431
# 1           0.357323                      0.353836         0.951192
# 2           0.749237                      0.745801         0.106032
# 3           0.764740                      0.769788         0.099660
# 4           0.666816                      0.667848         0.592284
#
#    P_Value_cpe  cpe_sig  bdi_split
# 0     0.801174        0          0
# 1     0.385504        0          0
# 2     0.562635        0          0
# 3     0.904915        0          0
# 4     0.919391        0          0
#
# [5 rows x 26 columns]

# %%
cpe_var = 'Z_Score_cpe'

# %%
# bar_order = ['dlpfc','vlpfc','dmpfc','ofc','ains','pins', 'acc','hpc','amy']
bar_order = keep_rois.copy()

# %%
results.groupby('roi').agg('mean',numeric_only=True)[cpe_var][bar_order]
# Out:
# roi
# dlpfc    0.007564
# vlpfc   -0.000384
# dmpfc   -0.111067
# ofc     -0.195508
# ains     0.260808
# pins     0.277840
# acc      0.165000
# amy      0.090884
# hpc     -0.318405
# Name: Z_Score_cpe, dtype: float64

# %%
roi_sig_info = []

for roi in results.roi.unique().tolist():
    roi_results = results[results.roi==roi]
    # ttest from zero 
    ttest_stat,ttest_pval = ttest_1samp(roi_results[cpe_var],popmean=0)
    # binomial test for significance 
    n = len(roi_results)
    x = np.sum(roi_results.cpe_sig)
    binom_test = scipy.stats.binomtest(x, n, p=0.05, alternative='greater')
    binom_pval = binom_test.pvalue
    binom_prop = binom_test.statistic
    ci_low     = binom_test.proportion_ci(confidence_level=0.95).low
    ci_high    = binom_test.proportion_ci(confidence_level=0.95).high
    # agg results 
    roi_sig_info.append(pd.DataFrame({'roi':roi,'n_total':n,'n_sig':x,'prop_sig':np.divide(x,n),
                                      'n_sig_highbdi':np.sum(roi_results[roi_results.bdi_split==1].cpe_sig),
                                      'ttest_stat':ttest_stat,'ttest_pval':ttest_pval,
                                      'binom_ci_low':ci_low,'binom_ci_high':ci_high,
                                      'binom_prop':binom_prop,'binom_pval':np.round(binom_pval,4)},index=[0]))

roi_sig_info = pd.concat(roi_sig_info).reset_index(drop=True)

# %%
roi_sig_info
# Out:
#      roi  n_total  n_sig  prop_sig  n_sig_highbdi  ttest_stat  ttest_pval  \
# 0    acc      193     16  0.082902              4    2.023012    0.044459
# 1  dmpfc      225     14  0.062222              2   -1.587928    0.113713
# 2    amy      113      3  0.026549              1    1.010508    0.314430
# 3   ains       71      8  0.112676              3    1.736270    0.086916
# 4  vlpfc       82      4  0.048780              0   -0.003272    0.997398
# 5    hpc      135     11  0.081481              0   -3.401120    0.000885
# 6    ofc      202     14  0.069307              2   -2.660257    0.008438
# 7   pins       60      5  0.083333              1    2.157388    0.035059
# 8  dlpfc      107     10  0.093458              3    0.069793    0.944490
#
#    binom_ci_low  binom_ci_high  binom_prop  binom_pval
# 0      0.052690            1.0    0.082902      0.0337
# 1      0.038006            1.0    0.062222      0.2380
# 2      0.007274            1.0    0.026549      0.9256
# 3      0.057316            1.0    0.112676      0.0252
# 4      0.016832            1.0    0.048780      0.5912
# 5      0.046366            1.0    0.081481      0.0765
# 6      0.042384            1.0    0.069307      0.1373
# 7      0.033411            1.0    0.083333      0.1803
# 8      0.051584            1.0    0.093458      0.0420

# %%
sig_rois = roi_sig_info[roi_sig_info.binom_pval<0.05]
sig_rois
# Out:
#      roi  n_total  n_sig  prop_sig  n_sig_highbdi  ttest_stat  ttest_pval  \
# 0    acc      193     16  0.082902              4    2.023012    0.044459
# 3   ains       71      8  0.112676              3    1.736270    0.086916
# 8  dlpfc      107     10  0.093458              3    0.069793    0.944490
#
#    binom_ci_low  binom_ci_high  binom_prop  binom_pval
# 0      0.052690            1.0    0.082902      0.0337
# 3      0.057316            1.0    0.112676      0.0252
# 8      0.051584            1.0    0.093458      0.0420

# %% [markdown]
# # Plot Results

# %%
fig_save_path = f'{fig_dir}{band}/'
os.makedirs(fig_save_path, exist_ok=True)

fig_id = f'{band}_perm_regression_cpe_only-coeff_barplot_{epoch_len}.pdf'

# %%
### WITHOUT RPE IN MODEL

ylabel = fr'${band}_{{zpow}} \sim cpe$'


plot_roi_model_results(results,'roi',cpe_var,bar_order=keep_rois,figsize=(12,5),color='k',
                       ylabel=ylabel,save_fig=True,save_dir=fig_save_path,fig_id=fig_id,dpi=400)

# %% [markdown]
# ## BDI correlations

# %%
sns.set_context("talk",rc={'axes.linewidth': 1.5})

for roi in results.roi.unique().tolist():
    
    corr_fig_id = f'{band}_{roi}_bdi_cpe-model_cpe_coeff_corr_{epoch_len}.pdf'
    
    roi_temp_data = results[results.roi==roi]
        
    fig,ax = plt.subplots(1,1,figsize=(4,3),dpi=400)

    sns.regplot(data=roi_temp_data,x='bdi',y='Z_Score_cpe',scatter=True,ci=95,
                fit_reg=True,color = 'k',x_jitter = 0.05,scatter_kws={'s':30}) #034975
    
    plt.xlabel('BDI-II')
    plt.xlim([0,40])
    
    plt.tick_params(length=0) 
    plt.ylabel(fr'${band}_{{zpow}} \sim cpe$')


    plt.title(f'{roi}')
    sns.despine()

    plt.savefig(f'{fig_save_path}{corr_fig_id}', format=corr_fig_id.split('.')[-1], metadata=None,
        bbox_inches='tight', pad_inches=0.1,dpi=400,
        facecolor='auto', edgecolor='auto',
        backend=None)

# %% [markdown]
# ### Test BDI Correlations via robust regression

# %%
### robust regression bdi ~ cpe coefficients
roi_rlm_dict = {}

for roi in results.roi.unique().tolist():
    roi_df = results[results.roi == roi]
    rlm = sm.RLM(roi_df.bdi.values, sm.add_constant(roi_df.Z_Score_cpe.values), M=sm.robust.norms.HuberT())
    rlm_results = rlm.fit()
    roi_rlm_dict[roi] = rlm_results
    print(roi)
    print(rlm_results.summary())
# Out:
# acc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  193
# Model:                            RLM   Df Residuals:                      191
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    10
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.9358      0.456     34.968      0.000      15.043      16.829
# x1             0.0634      0.399      0.159      0.874      -0.719       0.845
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# dmpfc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  225
# Model:                            RLM   Df Residuals:                      223
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.6610      0.431     36.299      0.000      14.815      16.507
# x1             0.7936      0.410      1.936      0.053      -0.010       1.597
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# amy
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  113
# Model:                            RLM   Df Residuals:                      111
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    18
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.2092      0.640     23.766      0.000      13.955      16.463
# x1            -0.2337      0.669     -0.349      0.727      -1.546       1.078
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# ains
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   71
# Model:                            RLM   Df Residuals:                       69
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.1759      0.779     20.767      0.000      14.649      17.703
# x1            -1.6579      0.607     -2.732      0.006      -2.847      -0.469
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# vlpfc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   82
# Model:                            RLM   Df Residuals:                       80
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    13
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.4631      0.653     23.664      0.000      14.182      16.744
# x1            -1.4745      0.618     -2.385      0.017      -2.686      -0.263
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# hpc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  135
# Model:                            RLM   Df Residuals:                      133
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.9925      0.529     30.234      0.000      14.956      17.029
# x1            -0.7354      0.468     -1.570      0.116      -1.653       0.182
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# ofc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  202
# Model:                            RLM   Df Residuals:                      200
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                     8
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.7389      0.498     31.616      0.000      14.763      16.715
# x1            -0.7032      0.470     -1.497      0.134      -1.624       0.217
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# pins
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                            RLM   Df Residuals:                       58
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.1308      1.002     16.096      0.000      14.167      18.095
# x1            -0.6431      0.975     -0.659      0.510      -2.555       1.269
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# dlpfc
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  107
# Model:                            RLM   Df Residuals:                      105
# Method:                          IRLS   Df Model:                            1
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 01 Oct 2024
# Time:                        10:26:01
# No. Iterations:                    22
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.7918      0.619     23.912      0.000      13.579      16.004
# x1             1.2767      0.554      2.303      0.021       0.190       2.363
# ==============================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
