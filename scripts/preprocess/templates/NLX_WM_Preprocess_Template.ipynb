# %% [markdown]
# # DA9 Preprocess
# 12/19/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/afink_lfp_pipeline/LFPAnalysis/')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
# Specify root directory for un-archived data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/'
anat_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/anat_recons/recon_labels/'
neural_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/data/'
behav_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/behavior_analysis/behavior_preprocessed/'

subj_id = 'DA9'
subj_format = ['nlx']
subj_site = ['UCD']

# %% [markdown]
# # Make mne_data

# %% [markdown]
# ### Get NLX File Information

# %%
load_path = f'{neural_dir}{subj_id}/raw_nlx/'
seeg_names = None
resp_names = None
ekg_names = None
eeg_names = None

# %%
### removing extraneous numbering from channel names 

# per Shawn, MSSM data seems to sometime have a "_0000.ncs" to "_9999.ncs" appended to the end of real data
pattern = re.compile(r"_\d{4}\.ncs")  # regex pattern to match "_0000.ncs" to "_9999.ncs"
ncs_files = [x for x in glob(f'{load_path}/*.ncs') if re.search(pattern, x)]
# just in case this changes in the future: 
if len(ncs_files) == 0: 
    ncs_files = glob(f'{load_path}/*.ncs')
    if not seeg_names:
        seeg_names = [x.split('/')[-1].replace('.ncs','') for x in glob(f'{load_path}/[R,L]*.ncs')]
else:
    if not seeg_names:
        seeg_names = [x.split('/')[-1].replace('.ncs','').split('_')[0] for x in glob(f'{load_path}/[R,L]*.ncs') if re.search(pattern, x)]

# %%
seeg_names = [x.lower() for x in seeg_names]

# %%
### empty vecs to load data into 

signals = [] #data
srs = [] #sampling rate
ch_name = [] #channel name
ch_type = [] #channel type (seeg, eeg etc.)

# %%
for chan_path in ncs_files:
    chan_name = chan_path.split('/')[-1].replace('.ncs','')
    # strip the file type off the end if needed 
    if '_' in chan_name:
        chan_name = chan_name.split('_')[0]
    try:
        fdata = nlx_utils.load_ncs(chan_path)
    except IndexError: 
        print(f'No data in channel {chan_name}')
        continue
    if eeg_names:
        if chan_name.lower() in eeg_names:
            ch_type.append('eeg')
    if resp_names:
        if chan_name.lower() in resp_names:
            ch_type.append('bio')
    if ekg_names:
        if chan_name.lower() in ekg_names: 
            ch_type.append('ecg') 
    if seeg_names: 
        if chan_name.lower() in seeg_names:
            ch_type.append('seeg')  
        elif chan_name.lower()[0] == 'u':
            # microwire data
            ch_type.append('seeg')  
    signals.append(fdata['data'])
    srs.append(fdata['sampling_rate'])
    ch_name.append(chan_name)
    if len(ch_type) < len(ch_name):
        ch_type.append('misc')
        print(f'Unidentified data type in {chan_name}') #this output should tell you what your photodiode name is
# Out:
# Unidentified data type in Photodiode

# %%
ch_name
# Out:
# ['RIL7',
#  'RIL6',
#  'LAD1',
#  'RFP8',
#  'RFP9',
#  'LHD8',
#  'LHD9',
#  'RHD1',
#  'LHD2',
#  'LHD3',
#  'RFP2',
#  'RFP3',
#  'LFP1',
#  'LHD5',
#  'LHD4',
#  'RHD7',
#  'RHD6',
#  'LFP7',
#  'LFP6',
#  'Photodiode',
#  'RFP5',
#  'RFP4',
#  'RIL1',
#  'LAD7',
#  'LAD6',
#  'RHD3',
#  'RHD2',
#  'LHD1',
#  'RFP1',
#  'LFP3',
#  'LFP2',
#  'LFP9',
#  'LFP8',
#  'RHD9',
#  'RHD8',
#  'LAD8',
#  'RIL4',
#  'RIL5',
#  'LAD3',
#  'LAD2',
#  'RIL8',
#  'RIL3',
#  'RIL2',
#  'LAD4',
#  'LAD5',
#  'LHD6',
#  'LHD7',
#  'RHD4',
#  'RHD5',
#  'LFP4',
#  'LFP5',
#  'RFP6',
#  'RFP7']

# %%
srs
# Out:
# [4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  32000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000]

# %% [markdown]
# ### Load and resample data

# %%
target_sr = 500 #downsampling to 500 to be consistent with other data - alternative = np.min(srs)
mne_data_resampled = []

# %%
### resampling to 500Hz

for sr in np.unique(srs):
    ch_ix = np.where(srs==sr)[0].astype(int)
    info = mne.create_info([x for ix, x in enumerate(ch_name) if ix in ch_ix], sr, [x for ix, x in enumerate(ch_type) if ix in ch_ix])
    mne_data_temp = mne.io.RawArray([x for ix, x in enumerate(signals) if ix in ch_ix], info)
    if sr != target_sr:
        # resample down to one sample rate 
        mne_data_temp.resample(sfreq=target_sr, npad='auto', n_jobs=-1)
        mne_data_resampled.append(mne_data_temp)
    else: 
        mne_data = mne_data_temp
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:  3.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  1.8min finished

# %%
### make sure timing is aligned post resampling --- check this 

#Because of the resampling, the end timings might not match perfectly:https://github.com/mne-tools/mne-python/issues/8257

if mne_data_resampled[0].tmax > mne_data_temp.tmax:
    mne_data_resampled[0].crop(tmin=0, tmax=mne_data_temp.tmax)
elif mne_data_resampled[0].tmax < mne_data_temp.tmax:
    mne_data_temp.crop(tmin=0, tmax=mne_data_resampled[0].tmax)

# %%
mne_data_resampled[0]
# Out:
# <RawArray | 52 x 7200008 (14400.0 s), ~2.79 GB, data loaded>

# %%
mne_data = mne_data_resampled[0]  #mne_data.add_channels([mne_data_temp]) to add more channels input mne object as list
mne_data.add_channels([mne_data_resampled[1]])
mne_data
# Out:
# <RawArray | 53 x 7200008 (14400.0 s), ~2.84 GB, data loaded>

# %%
#make channel names lowercase 
new_name_dict = {x:x.replace(" ", "").lower() for x in mne_data.ch_names}
mne_data.rename_channels(new_name_dict)
# Out:
# <RawArray | 53 x 7200008 (14400.0 s), ~2.84 GB, data loaded>

# %% [markdown]
# ### Photodiode
# - examine photodiode
# - save out before resampling/notch filtering *unless nlx - then you have to resample first

# %%
# Sanity check the photodiode
trig_ix = mne_data.ch_names.index('photodiode')
plt.plot(mne_data._data[trig_ix])
plt.title("Photodiode")
plt.show()

# %%
mne_data.save(f'{neural_dir}{subj_id}/photodiode.fif', picks='photodiode', overwrite=True)

# %%
mne_data.drop_channels(['photodiode'])
# Out:
# <RawArray | 52 x 7200008 (14400.0 s), ~2.79 GB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
mne_data.info['line_freq'] = 60
# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:    6.6s finished
# <RawArray | 52 x 7200008 (14400.0 s), ~2.79 GB, data loaded>

# %% [markdown]
# ### Anatomical Localization

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]

elec_locs
# Out:
#    label BN246label          x          y          z      mni_x      mni_y  \
# 0   LAD1    mAmyg_L -17.471760  10.790956  -9.888621 -14.202810  -3.822049
# 1   LAD2    mAmyg_L -22.261112  10.391291  -9.089589 -19.216283  -3.891958
# 2   LAD3    mAmyg_L -27.449577  10.391291  -8.690073 -24.550816  -3.667518
# 3   LAD4    lAmyg_L -32.238930   9.991626  -8.290558 -29.505896  -3.881665
# 4   LAD5    Unknown -37.427395   9.591962  -7.491526 -34.980580  -3.964504
# 5   LAD6     A38l_L -42.216747   9.192297  -7.092010 -40.067985  -4.078986
# 6   LAD7     A22r_L -47.405212   8.792632  -6.292979 -45.629547  -4.036446
# 7   LAD8     aSTS_L -52.194565   8.792632  -5.493947 -50.795900  -3.681195
# 8   LFP1     A11m_L -19.068211  44.362791  -1.498790 -13.605498  34.223324
# 9   LFP2    Unknown -19.866436  42.364467   2.895883 -15.002357  33.627828
# 10  LFP3    Unknown -20.664661  40.366144   7.290557 -16.498716  32.961508
# 11  LFP4    Unknown -21.462887  38.367820  11.685230 -17.896326  32.241880
# 12  LFP5    Unknown -21.862000  36.769161  16.878934 -18.765129  32.166487
# 13  LFP6    Unknown -22.660225  34.770838  21.273608 -20.050368  31.353275
# 14  LFP7    Unknown -23.857563  32.772514  25.268765 -21.760849  30.379224
# 15  LFP8    Unknown -24.256676  31.173856  30.062954 -22.613241  29.946276
# 16  LFP9   A9/46d_L -24.655788  29.974861  35.256659 -23.295524  29.836396
# 17  LHD1    rHipp_L -36.230057  -2.797644  -5.094432 -34.312688 -16.251584
# 18  LHD2    Unknown -41.019409  -4.396303  -4.295400 -39.396530 -17.576591
# 19  LHD3    Unknown -45.409649  -5.595297  -3.496369 -44.072953 -18.543409
# 20  LHD4     aSTS_L -50.199001  -6.794291  -2.297821 -49.255988 -19.508036
# 21  LHD5     aSTS_L -54.988354  -7.993285  -1.498790 -54.425407 -20.610042
# 22  LHD6     aSTS_L -59.777706  -9.192279  -0.300243 -59.550769 -21.491734
# 23  LHD7     aSTS_L -64.567059 -10.391273   0.898305 -64.624660 -22.280998
# 24  LHD8     aSTS_L -68.558186 -11.190603   1.697336 -68.825188 -22.750754
# 25  LHD9    Unknown -72.549313 -12.789261   2.895883 -73.144394 -23.984211
# 26  RFP1    Unknown   4.878551  40.765808   1.697336  10.846384  30.853666
# 27  RFP2    Unknown   6.075890  38.767485   5.292978  11.722088  30.042421
# 28  RFP3    Unknown   8.071453  37.568491  10.087167  13.597677  30.518742
# 29  RFP4    Unknown   9.667904  35.570167  14.082324  15.041016  29.799940
# 30  RFP5    Unknown  11.663467  34.371173  18.876513  16.990206  29.929020
# 31  RFP6    Unknown  13.659031  32.772514  22.871671  18.866793  29.279425
# 32  RFP7    Unknown  16.053707  31.173856  27.665860  21.120242  28.797799
# 33  RFP8    Unknown  17.251045  29.575197  31.661017  22.071351  28.134712
# 34  RFP9   A9/46d_R  19.246609  27.976538  36.055690  23.882084  27.546696
# 35  RHD1    cHipp_R  34.812004 -10.790938 -13.484262  40.723022 -26.952923
# 36  RHD2     aSTS_R  39.601357 -10.391273 -11.486684  45.545864 -25.881057
# 37  RHD3     aSTS_R  43.592484  -9.991609 -10.288136  49.543954 -25.118672
# 38  RHD4     aSTS_R  48.780949  -9.591944  -7.491526  54.620256 -24.186540
# 39  RHD5     aSTS_R  53.570301  -8.392950  -5.493947  59.551193 -22.822514
# 40  RHD6     A22r_R  57.162315  -7.993285  -3.895884  63.292082 -22.341744
# 41  RHD7     A22c_R  61.951668  -7.593620  -1.099274  68.271451 -21.637487
# 42  RHD8     A22c_R  65.942795  -7.193956   1.697336  72.442717 -20.729836
# 43  RHD9    Unknown  69.933922  -7.193956   4.493946  76.581292 -20.173621
# 44  RIL1    A20il_R  47.982723  -7.593620 -19.476999  55.340824 -25.841855
# 45  RIL2     A21c_R  51.973850  -6.794291 -16.680388  59.359762 -24.223515
# 46  RIL3     A21c_R  56.364090  -5.994962 -13.883778  63.690374 -22.824994
# 47  RIL4     aSTS_R  60.355217  -5.195632 -11.087168  67.518223 -21.511448
# 48  RIL5     aSTS_R  64.745457  -4.396303  -8.690073  71.885769 -20.352771
# 49  RIL6    Unknown  67.938358  -3.596973  -6.292979  75.117796 -19.043512
# 50  RIL7    Unknown  71.530373  -3.596973  -1.898306  78.595745 -18.046611
# 51  RIL8    Unknown  73.525936  -4.396303   1.297820  80.499318 -18.138487
# 52  uLFP     A11m_L -18.669098  45.961449  -4.694916 -12.868660  34.784378
# 53  uLHD    rHipp_L -31.440704  -1.598650  -6.292979 -29.224055 -15.554412
# 54  uRFP     A14m_R   3.681213  41.964802  -1.099274   9.819675  31.169018
# 55  uRHD    cHipp_R  31.219990  -9.991609 -15.082325  37.024548 -26.652733
#
#         mni_z       gm                                NMM               Anat  \
# 0  -19.553816     Gray                      Left Amygdala      Amygdala (SF)
# 1  -19.043659     Gray                      Left Amygdala      Amygdala (LB)
# 2  -19.122501     Gray                      Left Amygdala      Amygdala (LB)
# 3  -19.126831     Gray                      Left Amygdala      Amygdala (LB)
# 4  -18.722788    White         Left Cerebral White Matter            Unknown
# 5  -18.697161     Gray              Left PP planum polare           Area Id1
# 6  -18.194110     Gray         Left Cerebral White Matter            Unknown
# 7  -17.772288     Gray   Left STG superior temporal gyrus            Unknown
# 8  -16.416872    White         Left Cerebral White Matter           Area Fo1
# 9  -10.932631    White         Left Cerebral White Matter            Unknown
# 10  -5.510859    White         Left Cerebral White Matter            Unknown
# 11  -0.135568    White         Left Cerebral White Matter            Unknown
# 12   6.108525    White         Left Cerebral White Matter            Unknown
# 13  11.521497    White         Left Cerebral White Matter            Unknown
# 14  16.438791    White         Left Cerebral White Matter            Unknown
# 15  22.172272    White         Left Cerebral White Matter            Unknown
# 16  28.149742    White         Left Cerebral White Matter            Unknown
# 17 -12.556596    White         Left Cerebral White Matter            Unknown
# 18 -11.731309    White         Left Cerebral White Matter           Area Id1
# 19 -11.040606    White         Left Cerebral White Matter            Unknown
# 20 -10.130836     Gray     Left MTG middle temporal gyrus            Unknown
# 21  -9.555278     Gray     Left MTG middle temporal gyrus            Unknown
# 22  -8.177479     Gray     Left MTG middle temporal gyrus            Unknown
# 23  -6.649038     Gray     Left MTG middle temporal gyrus            Unknown
# 24  -5.657983     Gray     Left MTG middle temporal gyrus          Area TE 3
# 25  -4.006617  Unknown                            Unknown          Area TE 3
# 26  -9.935258    White        Right Cerebral White Matter            Unknown
# 27  -5.112309    White        Right Cerebral White Matter            Unknown
# 28   0.923071    White        Right Cerebral White Matter            Unknown
# 29   6.207899    White        Right Cerebral White Matter            Unknown
# 30  12.075196    White        Right Cerebral White Matter            Unknown
# 31  17.072808    White        Right Cerebral White Matter            Unknown
# 32  22.956152    White        Right Cerebral White Matter            Unknown
# 33  27.890259    White        Right Cerebral White Matter            Unknown
# 34  33.320108    White        Right Cerebral White Matter            Unknown
# 35 -12.497148    White        Right Cerebral White Matter  CA1 (Hippocampus)
# 36  -9.834224     Gray    Right MTG middle temporal gyrus            Unknown
# 37  -8.071407     Gray    Right MTG middle temporal gyrus            Unknown
# 38  -4.472426    White  Right STG superior temporal gyrus            Unknown
# 39  -2.337031     Gray  Right STG superior temporal gyrus            Unknown
# 40  -0.556919     Gray  Right STG superior temporal gyrus          Area TE 3
# 41   2.663703     Gray  Right STG superior temporal gyrus          Area TE 3
# 42   6.063386  Unknown  Right STG superior temporal gyrus          Area TE 3
# 43   9.600314  Unknown                            Unknown            Unknown
# 44 -19.637017     Gray  Right ITG inferior temporal gyrus            Unknown
# 45 -16.219123     Gray    Right MTG middle temporal gyrus            Unknown
# 46 -12.881924     Gray    Right MTG middle temporal gyrus            Unknown
# 47  -9.557690     Gray    Right MTG middle temporal gyrus          Area TE 3
# 48  -6.630202     Gray                            Unknown          Area TE 3
# 49  -3.759895  Unknown                            Unknown            Unknown
# 50   1.644589  Unknown                            Unknown            Unknown
# 51   5.653319  Unknown                            Unknown            Unknown
# 52 -20.547004     Gray     Left MOrG medial orbital gyrus           Area Fo1
# 53 -13.860388     Gray                   Left Hippocampus  CA2 (Hippocampus)
# 54 -13.640937    White        Right Cerebral White Matter           Area s32
# 55 -14.789898     Gray                  Right Hippocampus  CA1 (Hippocampus)
#
#                     AnatMacro    BN246  \
# 0     L ParaHippocampal Gyrus   L Amyg
# 1                  L Amygdala   L Amyg
# 2                  L Amygdala   L Amyg
# 3                  L Amygdala   L Amyg
# 4                     Unknown  Unknown
# 5                     Unknown    L STG
# 6     L Middle Temporal Gyrus    L STG
# 7     L Middle Temporal Gyrus    L MTG
# 8              L Rectal Gyrus    L OrG
# 9                     Unknown  Unknown
# 10                    Unknown  Unknown
# 11                    Unknown  Unknown
# 12                    Unknown  Unknown
# 13                    Unknown  Unknown
# 14                    Unknown  Unknown
# 15                    Unknown  Unknown
# 16     L Middle Frontal Gyrus    L MFG
# 17              L Hippocampus   L Hipp
# 18                    Unknown  Unknown
# 19                    Unknown  Unknown
# 20    L Middle Temporal Gyrus    L MTG
# 21    L Middle Temporal Gyrus    L MTG
# 22    L Middle Temporal Gyrus    L MTG
# 23    L Middle Temporal Gyrus    L MTG
# 24    L Middle Temporal Gyrus    L MTG
# 25                    Unknown  Unknown
# 26                      R ACC  Unknown
# 27                    Unknown  Unknown
# 28                    Unknown  Unknown
# 29                    Unknown  Unknown
# 30                    Unknown  Unknown
# 31                    Unknown  Unknown
# 32                    Unknown  Unknown
# 33                    Unknown  Unknown
# 34   R Superior Frontal Gyrus    R MFG
# 35              R Hippocampus   R Hipp
# 36                    Unknown    R MTG
# 37    R Middle Temporal Gyrus    R MTG
# 38    R Middle Temporal Gyrus    R MTG
# 39  R Superior Temporal Gyrus    R MTG
# 40  R Superior Temporal Gyrus    R STG
# 41  R Superior Temporal Gyrus    R STG
# 42  R Superior Temporal Gyrus    R STG
# 43                    Unknown  Unknown
# 44  R Inferior Temporal Gyrus    R ITG
# 45    R Middle Temporal Gyrus    R MTG
# 46    R Middle Temporal Gyrus    R MTG
# 47    R Middle Temporal Gyrus    R MTG
# 48    R Middle Temporal Gyrus    R MTG
# 49                    Unknown  Unknown
# 50                    Unknown  Unknown
# 51                    Unknown  Unknown
# 52   L Superior Orbital Gyrus    L OrG
# 53              L Hippocampus   L Hipp
# 54        R Mid Orbital Gyrus    R OrG
# 55    R ParaHippocampal Gyrus   R Hipp
#
#                                      YBA_1  \
# 0             Left parahippocampal gyrus A
# 1                  Left amygdala superior
# 2                  Left amygdala superior
# 3                  Left amygdala superior
# 4                                  Unknown
# 5           Left superior temporal gyrus A
# 6          Left superior temporal gyrus B
# 7          Left superior temporal gyrus B
# 8                                  Unknown
# 9                                  Unknown
# 10                                 Unknown
# 11                                 Unknown
# 12                                 Unknown
# 13                                 Unknown
# 14                                 Unknown
# 15                                 Unknown
# 16                                 Unknown
# 17                  Left hippocampus body
# 18                                 Unknown
# 19                                 Unknown
# 20   Left superior middle temporal gyrus C
# 21   Left superior middle temporal gyrus C
# 22   Left superior middle temporal gyrus C
# 23   Left superior middle temporal gyrus C
# 24   Left superior middle temporal gyrus C
# 25                                 Unknown
# 26                 Right cingulate gyrus D
# 27                                 Unknown
# 28                                 Unknown
# 29                                 Unknown
# 30                                 Unknown
# 31                                 Unknown
# 32                                 Unknown
# 33                                 Unknown
# 34          Right middle frontal gyrus 4 A
# 35                                 Unknown
# 36  Right superior middle temporal gyrus C
# 37  Right superior middle temporal gyrus C
# 38        Right superior temporal gyrus D
# 39        Right superior temporal gyrus D
# 40        Right superior temporal gyrus D
# 41        Right superior temporal gyrus D
# 42        Right superior temporal gyrus D
# 43                                 Unknown
# 44  Right inferior middle temporal gyrus C
# 45  Right inferior middle temporal gyrus C
# 46  Right superior middle temporal gyrus C
# 47  Right superior middle temporal gyrus C
# 48  Right superior middle temporal gyrus C
# 49                                 Unknown
# 50                                 Unknown
# 51                                 Unknown
# 52                Left frontal orbital 4 A
# 53                    Left hippocampus pes
# 54                  Right frontal pole 1 B
# 55                 Right hippocampus body
#
#                         ManualExamination
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                      WM
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                      WM
# 9                                      WM
# 10                                     WM
# 11                                     WM
# 12                                     WM
# 13                                     WM
# 14                                     WM
# 15          Left middle frontal gyrus 4 B
# 16                                     WM
# 17                                    NaN
# 18                                     WM
# 19                                     WM
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    OOB
# 26                                     WM
# 27                                     WM
# 28                                     WM
# 29                                     WM
# 30                                     WM
# 31                                     WM
# 32                                     WM
# 33                                     WM
# 34                                     WM
# 35  Right basal inferior temporal gyrus C
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                                    OOB
# 43                                    OOB
# 44                                    NaN
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    OOB
# 49                                    OOB
# 50                                    OOB
# 51                                    OOB
# 52                                    NaN
# 53                                    NaN
# 54                                     WM
# 55                                    NaN

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) #print extra channels in mne_data.ch_names and make sure none of them are neural channels (will be EEG etc.)
# Out:
# []

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is less than the number of electrodes in the localization file

# %%
unmatched_seeg
# Out:
# []

# %%
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of {len(left_seeg_names)} left sEEG and {len(right_seeg_names)} right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 26 left sEEG and 26 right sEEG electrodes
# We have a total of 52 sEEG electrodes

# %%
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawArray | 52 x 7200008 (14400.0 s), ~2.79 GB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawArray | 52 x 7200008 (14400.0 s), ~2.79 GB, data loaded>

# %% [markdown]
# ## Signal Cleaning
# Methods:
# - Remove all channels that are obviously noise
# - Be LIBERAL with bad labeling - these channels are NOT removed from the dataset, they are just NOT USED to rereference other channels.
# - This process is iterative depending on how TFRs look.

# %%
#automatic detection - not stringent enough usually
# bads = lfp_preprocess_utils.detect_bad_elecs(mne_data, sEEG_mapping_dict)
# mne_data.info['bads'] = bads
# bads
# Out:
# ['lhd9', 'ril7']

# %%
ch_names = list(elec_locs.label.str.lower())
pattern = '[0-9]'
ch_names_no_num = [re.sub(pattern, '', i) for i in ch_names]
probe_names = np.unique(ch_names_no_num)

# %%
probe_ch_counts = {} #need this to select channel number for visualization
for p in probe_names:
    c = ch_names_no_num.count(p)
    probe_ch_counts[p] = c

# %%
probe_ch_counts
# Out:
# {'lad': 8,
#  'lfp': 9,
#  'lhd': 9,
#  'rfp': 9,
#  'rhd': 9,
#  'ril': 8,
#  'ulfp': 1,
#  'ulhd': 1,
#  'urfp': 1,
#  'urhd': 1}

# %%
# %matplotlib notebook 
fig = mne_data.plot(start=0, duration=1000, n_channels=15, scalings=mne_data._data.max())
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="800.0000211927631">
# <img src="data:image/png;base64,..." width="500.00001324547696">

# %%
##save info in SWB_electrode_info spreadsheet!
mne_data.info['bads']
mne_data.info['bads'] =['lad7',
 'lad6',
 'lad1',
 'lhd2',
 'lhd3',
 'lhd9',
 'lhd1',
 'lad3',
 'lad8',
 'lad2',
 'lad4',
 'lad5',
 'ril8']

# %%
mne_data.info #sanity check that bads info saved
# Out:
# <Info | 10 non-empty values
#  bads: 13 items (lad7, lad6, lad1, lhd2, lhd3, lhd9, lhd1, lad3, lad8, ...)
#  ch_names: ril7, ril6, lad1, rfp8, rfp9, lhd8, lhd9, rhd1, lhd2, lhd3, ...
#  chs: 52 sEEG
#  custom_ref_applied: False
#  dig: 52 items (52 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 52
#  projs: []
#  sfreq: 500.0 Hz
# >

# %% [markdown]
# # Re-referencing
# - wm reref
# - bipolar reref

# %%
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
mne_data = mne.io.read_raw_fif(f'{neural_dir}{subj_id}/raw_ieeg.fif', preload=True)

# %% [markdown]
# ### WM Re-ref

# %%
# Re-reference neural data
mne_data_wm_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='wm', 
                                              site='MSSM')
# Out:
# Number of electrodes in the mne file is less than the number of electrodes in the localization file

# %%
mne_data_wm_reref
# Out:
# <Raw | raw_ieeg.fif, 28 x 7200008 (14400.0 s), ~1.50 GB, data loaded>

# %%
mne_data_wm_reref.ch_names
# Out:
# ['lad1-lfp1',
#  'lad2-lfp4',
#  'lad3-lfp4',
#  'lad4-lfp4',
#  'lad5-lfp4',
#  'lad6-lfp4',
#  'lad7-lfp4',
#  'lad8-lfp4',
#  'lfp8-lfp9',
#  'lhd1-lfp4',
#  'lhd2-lfp4',
#  'lhd3-lfp4',
#  'lhd4-lfp4',
#  'lhd5-lfp6',
#  'lhd6-lfp6',
#  'lhd7-lfp6',
#  'lhd8-lfp6',
#  'rhd1-rfp3',
#  'rhd2-rfp6',
#  'rhd3-rfp6',
#  'rhd4-rfp7',
#  'rhd5-rfp8',
#  'rhd6-rfp8',
#  'rhd7-rfp9',
#  'ril1-rfp2',
#  'ril2-rfp6',
#  'ril3-rfp6',
#  'ril4-rfp7']

# %%
mne_data_wm_reref.save(f'{neural_dir}{subj_id}/wm_ref_ieeg.fif',overwrite=True)

# %% [markdown]
# ### Bipolar Re-ref

# %%
# Re-reference neural data
mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')
# Out:
# Number of electrodes in the mne file is less than the number of electrodes in the localization file

# %%
mne_data_bp_reref.ch_names
# Out:
# ['lfp7-lfp8',
#  'lfp8-lfp9',
#  'lhd4-lhd5',
#  'lhd5-lhd6',
#  'lhd6-lhd7',
#  'lhd7-lhd8',
#  'rhd1-rhd2',
#  'rhd2-rhd3',
#  'rhd3-rhd4',
#  'rhd4-rhd5',
#  'rhd5-rhd6',
#  'rhd6-rhd7',
#  'ril1-ril2',
#  'ril2-ril3',
#  'ril3-ril4']

# %%
mne_data_bp_reref
# Out:
# <Raw | raw_ieeg.fif, 15 x 7200008 (14400.0 s), ~824.0 MB, data loaded>

# %%
mne_data_bp_reref.save(f'{neural_dir}{subj_id}/bp_ref_ieeg.fif',overwrite=True)

# %% [markdown]
# ### Save mne data

# %%
mne_data.save(f'{neural_dir}{subj_id}/raw_ieeg.fif',overwrite=True) #this now contains oob channels as 'bads'

# %% [markdown]
# # Epoching + TFRs
# - Check whether data is ready to be analyzed - if this step shows noise then steps above should be repeated
# - Align photodiode to behavior
# - Epoch data (and mark bad epochs)
# - Baseline data
# - Visualize TFRs

# %%
#remove mne_data from environment to save memory 
del mne_data, mne_data_bp_reref, mne_data_wm_reref

# %%
#add directory for TFRs
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
tfr_dir = f'{base_dir}/figs/TFRs/{subj_id}/all_trials/'
os.makedirs(tfr_dir,exist_ok = True) #added so you don't have to manually make subject folders in clean_data
#load behavior data
behav_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/behavior_analysis/behavior_preprocessed/'
behav_df = pd.read_csv(f'{behav_dir}{subj_id}_task_data')
behav_df = behav_df[behav_df.columns.drop(list(behav_df.filter(regex='Unnamed')))]
behav_df = behav_df[behav_df['FeedbackOnset'] != 0] #remove fail trials from behav df
beh_ts = behav_df['TrialOnset'] #timestamp that should be aligned to photodiode 
#load photodiode data
photodiode_data = mne.io.read_raw_fif(f'{neural_dir}{subj_id}/photodiode.fif', preload=True)

# %% [markdown]
# ### Photodiode Alignment

# %%
### Photodiode alignment

# Synchronize to the photodiode or whatever your neural sync signal is
slope, offset = sync_utils.synchronize_data(beh_ts, 
                                            photodiode_data, 
                                            smoothSize=11, windSize=15, height=1)
# Out:
# 30 blocks
# ..............................
#
# found matches for 60 of 459 pulses
# 22 blocks
# ......................
#
# found matches for 20 of 459 pulses

# %%
print(slope,offset)
# Out:
# 0.9807423538824177 7367.509531147343

# %% [markdown]
# ## Epoch Data
# - Epoch neural data into trial epochs
# - Add behavioral data to epochs metadata
# - Save epochs
# - Baseline + decompose data into TFRs
# - Plot + save TFRs (examine quality)

# %% [markdown]
# ### Epoch data

# %%
# IED removal requires that we set some parameters for IED detection. 
# 1. peak_thresh: how many stds should they exceed the baseline by? 
# 2. closeness_thresh: how close should they be allowed to be (in sec) to other candidate IEDs? 
# 3. width_thresh: how wide should they have to be (in sec)?

# Defaults:
IED_args = {'peak_thresh':4,
           'closeness_thresh':0.25, 
           'width_thresh':0.2}

# %%
# Create a dictionary with your event name (matching your dataframe), and the time-window for the event
evs = {'TrialOnset': [-1.0, 0], #ITI is always at least one second + 10ms buffer for wavelet padding (no horizontal smearing)
       'DecisionOnset': [0, 5.0]} #1 sec decision period + 2 second outcome + 3 second counterfactual

# %%
epochs_all_evs = {f'{x}': np.nan for x in evs}

# %%
### Epoch WM reref data for now 
for event in evs.keys():
    # Make the epochs. 
    ev_epochs = lfp_preprocess_utils.make_epochs(load_path=f'{neural_dir}{subj_id}/wm_ref_ieeg.fif', 
#     ev_epochs = lfp_preprocess_utils.make_epochs(load_path=f'{neural_dir}{subj_id}/bp_ref_ieeg.fif', 
                 slope=slope, offset=offset,
                 behav_name=event, behav_times=behav_df[event].values, 
                 ev_start_s=evs[event][0], ev_end_s=evs[event][1], buf_s = 1.0, IED_args=IED_args) #1.0 buf unsaved

    epochs_all_evs[event] = ev_epochs
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    8.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   15.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    6.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   11.4s finished

# %%
epochs_all_evs
# Out:
# {'TrialOnset': <Epochs |  149 events (all good), -2 - 1 sec, baseline off, ~47.8 MB, data loaded, with metadata,
#   'TrialOnset': 149>,
#  'DecisionOnset': <Epochs |  149 events (all good), -1 - 6 sec, baseline off, ~111.5 MB, data loaded, with metadata,
#   'DecisionOnset': 149>}

# %% [markdown]
# ### Add behavioral data to metadata

# %%
behav_df
# Out:
#      Round  Trial Num TrialType   TrialOnset  ChoiceOnset  DecisionOnset  \
# 0        1       45.0       mix   458.262575   458.273875     462.041225
# 1        2      146.0      loss   468.814804   468.828686     473.819151
# 2        3      140.0      loss   480.509956   480.510710     484.830998
# 3        4       57.0      gain   497.135665   497.142355     500.407262
# 4        5       47.0       mix   507.397588   507.406724     511.335869
# ..     ...        ...       ...          ...          ...            ...
# 145    146      127.0      loss  2211.392241  2211.392976    2214.280426
# 146    147       78.0      gain  2220.904660  2220.905430    2225.208157
# 147    148       85.0      gain  2236.130865  2236.138261    2238.452797
# 148    149      148.0      loss  2245.193557  2245.194353    2247.982401
# 149    150      137.0      loss  2255.055756  2255.063637    2257.678562
#
#      FeedbackOnset        RT  SafeBet  LowBet  ...  totalCPE decisionCPE  \
# 0       462.049006  3.767350      0.0   -1.10  ...      1.10        1.10
# 1       473.826753  4.990465     -0.6   -1.68  ...     -0.60       -0.60
# 2       484.838941  4.320288     -0.5   -2.50  ...      2.00        2.00
# 3       502.416627  3.264907      0.2    0.00  ...      0.63        0.43
# 4       511.343683  3.929145      0.0   -1.10  ...      1.10        1.10
# ..             ...       ...      ...     ...  ...       ...         ...
# 145    2214.288188  2.887450     -0.4   -1.26  ...     -0.40       -0.40
# 146    2227.218260  4.302726      0.4    0.00  ...     -1.44       -0.40
# 147    2240.478945  2.314536      0.5    0.00  ...      1.24        0.74
# 148    2247.990169  2.788048     -0.6   -2.16  ...      1.56        1.56
# 149    2257.683299  2.614925     -0.5   -1.58  ...      1.08        1.08
#
#     totalRegret decisionRegret totalRelief decisionRelief  totalCF  \
# 0          0.00            0.0        1.10           1.10    -1.10
# 1         -0.60           -0.6        0.00           0.00     0.00
# 2          0.00            0.0        2.00           2.00    -2.50
# 3          0.00            0.0        0.63           0.43     0.00
# 4          0.00            0.0        1.10           1.10    -1.10
# ..          ...            ...         ...            ...      ...
# 145       -0.40           -0.4        0.00           0.00     0.00
# 146       -1.44           -0.4        0.00           0.00     1.44
# 147        0.00            0.0        1.24           0.74     0.00
# 148        0.00            0.0        1.56           1.56    -2.16
# 149        0.00            0.0        1.08           1.08    -1.58
#
#      decisionCF   pRPE  nRPE
# 0         -1.10  0.000  0.00
# 1          0.00  0.000  0.00
# 2         -2.50  0.000  0.00
# 3          0.20  0.315  0.00
# 4         -1.10  0.000  0.00
# ..          ...    ...   ...
# 145        0.00  0.000  0.00
# 146        0.40  0.000 -0.72
# 147        0.50  0.620  0.00
# 148       -2.16  0.000  0.00
# 149       -1.58  0.000  0.00
#
# [149 rows x 32 columns]

# %%
behav_params = ['SafeBet', 'LowBet', 'HighBet','GambleChoice', 'Outcome',
                'Profit', 'TotalProfit', 'GambleEV', 'CR', 'choiceEV', 'RPE',
                'totalCPE', 'decisionCPE', 'totalRegret', 'decisionRegret',
                'totalRelief', 'decisionRelief', 'totalCF', 'decisionCF', 'pRPE','nRPE']

# %%
for event in evs.keys():

    event_metadata = epochs_all_evs[event].metadata.copy()
    
    #independent vars
    for param in behav_params: 
        event_metadata[param] = behav_df[param].tolist()

    epochs_all_evs[event].metadata = event_metadata

# %%
epochs_all_evs[event].metadata
# Out:
#                 lad1-lfp1             lad2-lfp4             lad3-lfp4  \
# 0                     NaN                   NaN                   NaN
# 1              [7834.178]                   NaN                   NaN
# 2                     NaN             [7845.06]            [7845.064]
# 3    [7859.522, 7863.208]            [7859.722]            [7859.726]
# 4              [7870.236]             [7870.24]            [7870.244]
# ..                    ...                   ...                   ...
# 144                   NaN                   NaN                   NaN
# 145                   NaN                   NaN                   NaN
# 146            [9567.776]            [9567.782]            [9567.784]
# 147  [9572.952, 9575.908]  [9573.102, 9575.908]  [9573.104, 9575.916]
# 148                   NaN                   NaN                   NaN
#
#                lad4-lfp4            lad5-lfp4   lad6-lfp4 lad7-lfp4 lad8-lfp4  \
# 0                    NaN                  NaN         NaN       NaN       NaN
# 1             [7834.222]           [7834.224]         NaN       NaN       NaN
# 2              [7845.06]                  NaN         NaN       NaN       NaN
# 3             [7859.724]                  NaN         NaN       NaN       NaN
# 4             [7870.246]                  NaN         NaN       NaN       NaN
# ..                   ...                  ...         ...       ...       ...
# 144                  NaN                  NaN         NaN       NaN       NaN
# 145                  NaN                  NaN         NaN       NaN       NaN
# 146           [9567.786]                  NaN         NaN       NaN       NaN
# 147  [9573.112, 9575.92]  [9573.11, 9575.924]  [9575.924]       NaN       NaN
# 148                  NaN                  NaN         NaN       NaN       NaN
#
#     lfp8-lfp9 lhd1-lfp4  ... totalCPE decisionCPE totalRegret decisionRegret  \
# 0         NaN       NaN  ...     1.10        1.10        0.00            0.0
# 1         NaN       NaN  ...    -0.60       -0.60       -0.60           -0.6
# 2         NaN       NaN  ...     2.00        2.00        0.00            0.0
# 3         NaN       NaN  ...     0.63        0.43        0.00            0.0
# 4         NaN       NaN  ...     1.10        1.10        0.00            0.0
# ..        ...       ...  ...      ...         ...         ...            ...
# 144       NaN       NaN  ...    -0.40       -0.40       -0.40           -0.4
# 145       NaN       NaN  ...    -1.44       -0.40       -1.44           -0.4
# 146       NaN       NaN  ...     1.24        0.74        0.00            0.0
# 147       NaN       NaN  ...     1.56        1.56        0.00            0.0
# 148       NaN       NaN  ...     1.08        1.08        0.00            0.0
#
#     totalRelief decisionRelief totalCF decisionCF   pRPE  nRPE
# 0          1.10           1.10   -1.10      -1.10  0.000  0.00
# 1          0.00           0.00    0.00       0.00  0.000  0.00
# 2          2.00           2.00   -2.50      -2.50  0.000  0.00
# 3          0.63           0.43    0.00       0.20  0.315  0.00
# 4          1.10           1.10   -1.10      -1.10  0.000  0.00
# ..          ...            ...     ...        ...    ...   ...
# 144        0.00           0.00    0.00       0.00  0.000  0.00
# 145        0.00           0.00    1.44       0.40  0.000 -0.72
# 146        1.24           0.74    0.00       0.50  0.620  0.00
# 147        1.56           1.56   -2.16      -2.16  0.000  0.00
# 148        1.08           1.08   -1.58      -1.58  0.000  0.00
#
# [149 rows x 49 columns]

# %% [markdown]
# ### Save raw epoched data

# %%
for event in evs.keys():
    epochs_all_evs[event].save(f'{neural_dir}{subj_id}/wm_epoch_{event}.fif', overwrite=True)
#     epochs_all_evs[event].save(f'{neural_dir}{subj_id}/bp_epoch_{event}.fif', overwrite=True)

# %% [markdown]
# ### Baseline + Decompose into TFRs

# %%
# Explicitly define a list of analysis events and the baseline event. Should correspond to the dict
analysis_evs = ['DecisionOnset']
baseline_ev = 'TrialOnset'
evs = {'TrialOnset': [-1.0, 0], #maybe increase to full second to take cycles up to 4
       #ITI is always at least one second + 10ms buffer for wavelet padding (no horizontal smearing)
       'DecisionOnset': [0, 5.0]} #1 sec decision period + 2 second outcome + 3 second counterfactual

# %%
# Set some spectrogram parameters 
freqs = np.logspace(*np.log10([2, 200]), num=30)
n_cycles = 3
sr = 500.0 
buf = 1.0
buf_ix = int(buf*sr)

# %%
epochs_all_baseline = {} #removed unecessary 'decisiononset' empty key

# %%
#baseline epoch - 
event = 'TrialOnset'
epochs = epochs_all_evs[event]

good_chans = [x for x in epochs.ch_names if x not in epochs.info['bads']]
picks = [x for x in good_chans]

pow_struct = np.nan * np.ones([epochs._data.shape[0], 
                       epochs._data.shape[1], len(freqs), 
                       epochs._data.shape[-1]])

for ch_ix in np.arange(epochs._data.shape[1]): 
    ch_data = epochs._data[:, ch_ix:ch_ix+1, :]
    bad_epochs  = np.where(epochs.metadata[epochs.ch_names[ch_ix]].notnull())[0]
    good_epochs = np.delete(np.arange(ch_data.shape[0]), bad_epochs)
    ch_data = np.delete(ch_data, bad_epochs, axis=0)
    ch_pow = mne.time_frequency.tfr_array_morlet(ch_data, sfreq=epochs.info['sfreq'], 
                                        freqs=freqs, n_cycles=n_cycles, zero_mean=False, 
                                        use_fft=True, output='power', n_jobs=1)

    pow_struct[good_epochs, ch_ix, :, :] = ch_pow[:, 0, :, :]

temp_pow = mne.time_frequency.EpochsTFR(epochs.info, pow_struct, 
                                        epochs.times, freqs)
temp_pow.crop(tmin=evs[event][0], tmax=evs[event][1])

epochs_all_baseline[event] = temp_pow

# %%
epochs_all_baseline
# Out:
# {'TrialOnset': <EpochsTFR | time : [-1.000000, 0.000000], freq : [2.000000, 200.000000], epochs : 149, channels : 28, ~478.5 MB>}

# %%
power_epochs = {}

# %%
event = 'DecisionOnset'

epochs = epochs_all_evs[event]

# Let's make sure we only do this for good channels
good_chans = [x for x in epochs.ch_names if x not in epochs.info['bads']]
picks = [x for x in good_chans]

pow_struct = np.nan * np.ones([epochs._data.shape[0], 
                       epochs._data.shape[1], len(freqs), 
                       epochs._data.shape[-1]])

for ch_ix in np.arange(epochs._data.shape[1]): 
    ch_data = epochs._data[:, ch_ix:ch_ix+1, :]
    bad_epochs  = np.where(epochs.metadata[epochs.ch_names[ch_ix]].notnull())[0] 
    good_epochs = np.delete(np.arange(ch_data.shape[0]), bad_epochs)
    ch_data = np.delete(ch_data, bad_epochs, axis=0) #this is where bad epochs for ch are deleted!!
    ch_pow = mne.time_frequency.tfr_array_morlet(ch_data, sfreq=epochs.info['sfreq'], 
                                        freqs=freqs, n_cycles=n_cycles, zero_mean=False, 
                                        use_fft=True, output='power', n_jobs=1)

    pow_struct[good_epochs, ch_ix, :, :] = ch_pow[:, 0, :, :]

temp_pow = mne.time_frequency.EpochsTFR(epochs.info, pow_struct, 
                                        epochs.times, freqs)

temp_pow.crop(tmin=evs[event][0], tmax=evs[event][1])


baseline_corrected_power = lfp_preprocess_utils.baseline_trialwise_TFR(data=temp_pow.data, 
                                                  baseline_mne=epochs_all_baseline['TrialOnset'], 
                                                  mode='zscore', 
                                                  trialwise=True, ## make sure this is true!
                                                  baseline_only=False)


zpow = mne.time_frequency.EpochsTFR(epochs.info, baseline_corrected_power, 
                                temp_pow.times, freqs)

zpow.metadata = epochs_all_evs[event].metadata

power_epochs[event] = zpow

# %%
power_epochs['DecisionOnset']
# Out:
# <EpochsTFR | time : [0.000000, 5.000000], freq : [2.000000, 200.000000], epochs : 149, channels : 28, ~2.33 GB>

# %%
#conda install -c conda-forge h5io must install to save tfr data
# power_epochs['DecisionOnset'].save(f'{neural_dir}{subj_id}/bp_pow_epochs-tfr.h5', overwrite=True)
power_epochs['DecisionOnset'].save(f'{neural_dir}{subj_id}/wm_pow_epochs-tfr.h5', overwrite=True)

# %% [markdown]
# ## Plot TFRs

# %%
event = 'DecisionOnset'
yticks = [4, 12, 30, 60, 90, 120, 150, 180, 200]
good_ch = [x for x in power_epochs[event].ch_names if '-' in x]
save_path = tfr_dir
date = '01082024' #add date to file name 


for ch in good_ch:
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    times = power_epochs[event].times
    plot_data = np.nanmean(np.nanmean(power_epochs[event].copy().pick_channels([ch]).data, axis=0), axis=0)

    im = ax.imshow(plot_data,
            extent=[times[0], times[-1], freqs[0], freqs[-1]], interpolation='Bicubic',
            aspect='auto', origin='lower', cmap='RdBu_r',vmin = -np.nanmax(np.abs(plot_data)), vmax = np.nanmax(np.abs(plot_data)))
    ax.set(yticks=yticks, xlabel='Time (s)', ylabel='Frequency',title=f'{ch} Encoding')
    ax.yaxis.set_tick_params(labelsize=8)
    fig.colorbar(im, ax=ax)
    plt.savefig(f'{save_path}/{ch}_{date}_wmref.png', format='png', metadata=None,
#     plt.savefig(f'{save_path}/{ch}_{date}_bp_ref.png', format='png', metadata=None,
    bbox_inches=None, pad_inches=0.1,
    facecolor='auto', edgecolor='auto',
    backend=None)
    plt.close()
