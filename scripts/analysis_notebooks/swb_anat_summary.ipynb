# %% [markdown]
# # SWB Anatomical Coverage
# Created: 04/07/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp, pearsonr, spearmanr
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import re
import datetime
import scipy
import random
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor

import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/sc/arion/projects/guLab/Alie/SWB/ephys_analysis/LFPAnalysis/')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
# Specify root directory for un-archived data and results 
base_dir = '/sc/arion/projects/guLab/Alie/SWB/'
anat_dir = f'{base_dir}ephys_analysis/recon_labels/'
neural_dir = f'{base_dir}ephys_analysis/data/'
behav_dir = f'{base_dir}swb_behav_models/data/behavior_preprocessed/'

date = datetime.date.today().strftime('%m%d%Y')
print(date)
# Out:
# 04082024

# %% [markdown]
# ## Data Loading
# - ROI labels for all bp reref elecs
# - Current subj list for CCN 2024

# %%
# Subj list for CCN 2024
subj_ids = list(pd.read_excel(f'{base_dir}ephys_analysis/subj_info/SWB_subjects.xlsx', sheet_name='Usable_Subjects', usecols=[0]).PatientID)
n_subj = len(subj_ids)
# subj_ids

# %%
# load bp reref ch names 
reref_ch_all_subj  = {}

for subj_id in subj_ids:
    # load reref data 
    bp_data = mne.io.read_raw_fif(f'{neural_dir}{subj_id}/bp_ref_ieeg.fif', preload=False,verbose=0)
    subj_ch = bp_data.ch_names
    # save info 
    reref_ch_all_subj[subj_id]  = subj_ch
# reref_ch_all_subj

# %%
# load anat recon files 
anat_info_all_subj = {}

for subj_id in subj_ids:
    # load anat recon file 
    subj_anat_df = pd.read_csv(f'{anat_dir}{subj_id}_labels.csv')
    # save info 
    anat_info_all_subj[subj_id] = subj_anat_df 
# anat_info_all_subj

# %%
# Anatomical Localization Info - Lab YBA ROIs  

# ROI labels for YBA regions
roi_label_info = pd.read_excel(f'{base_dir}ephys_analysis/LFPAnalysis/LFPAnalysis/YBA_ROI_labelled.xlsx',
                               usecols=['Hemisphere','Lobe','Region','Custom','Long.name'])
roi_label_info = roi_label_info.apply(lambda x: x.str.lower())
roi_label_info = roi_label_info.apply(lambda x: x.str.strip())
roi_label_info
# Out:
#     Hemisphere      Lobe         Region         Custom  \
# 0         left  temporal  temporal pole  temporal pole
# 1         left  temporal  temporal pole  temporal pole
# 2         left  temporal  temporal pole  temporal pole
# 3         left  temporal  temporal pole  temporal pole
# 4         left  temporal  temporal pole  temporal pole
# ..         ...       ...            ...            ...
# 685      right    insula         insula           pins
# 686      right    insula         insula           pins
# 687      right    insula         insula           pins
# 688      right    insula         insula           pins
# 689      right    insula         insula           pins
#
#                                 Long.name
# 0           left superior temporal pole a
# 1           left superior temporal pole b
# 2           left superior temporal pole b
# 3           left superior temporal pole c
# 4           left superior temporal pole d
# ..                                    ...
# 685   right anterior long insular gyrus d
# 686  right posterior long insular gyrus a
# 687  right posterior long insular gyrus b
# 688  right posterior long insular gyrus c
# 689  right posterior long insular gyrus d
#
# [690 rows x 5 columns]

# %% [markdown]
# ## ROI labels

# %%
roi_reref_labels_all_subj = {}
roi_reref_labels_master = []
unknown_subj = {}

for subj_id in subj_ids:
    # get subj reref ch
    reref_ch_names = reref_ch_all_subj[subj_id]
    # get anat file 
    anat_df = anat_info_all_subj[subj_id]
    anat_df['label'] = anat_df['label'].str.lower()
    anat_df['final_loc'] = [row.ManualExamination.lower().strip() if pd.isna(row.ManualExamination) == False else row.YBA_1.lower().strip() for index, row in anat_df.iterrows()]
    if np.sum(anat_df.final_loc.unique().tolist().count('unknown'))!=0:
        unknown_subj[subj_id] = np.sum(anat_df.final_loc.unique().tolist().count('unknown'))
    
    # check which elec should be used for roi label 
    loc4roi = []
    ch_label4roi = []
    ch_type4roi = []
    for ch in reref_ch_names:
        anode = ch.split('-')[0]
        cathode = ch.split('-')[1]
        anode_loc = anat_df.final_loc[anat_df.label == anode].str.lower().tolist()
        cathode_loc = anat_df.final_loc[anat_df.label == cathode].str.lower().tolist()
        if (anode_loc[0] == 'wm') | (anode_loc[0] == 'unknown'): # if anode is in wm or labeled unknown check cathode
            if (cathode_loc[0] == 'wm') | (cathode_loc[0] == 'unknown'): # check if cathode also wm or unknown 
                if (anode_loc[0] == 'wm') & (cathode_loc[0] == 'unknown'): # if anode is wm and cathode is unknown, use anode label
                    loc4roi.append('wm') # roi location detail 
                    ch_label4roi.append(anode) # ch label used for roi 
                    ch_type4roi.append('anode') # whether anode vs cathode was used 
                else: # if cathode is wm and anode is wm or unknown, use cathode, if cathode is unknown and anode is unknown use cathode
                    loc4roi.append(cathode_loc[0]) # roi location detail 
                    ch_label4roi.append(cathode) # ch label used for roi 
                    ch_type4roi.append('cathode') # whether anode vs cathode was used 
            else: # if cathode is in gm use cathode
                loc4roi.append(cathode_loc[0]) # roi location detail 
                ch_label4roi.append(cathode) # ch label used for roi
                ch_type4roi.append('cathode') # whether anode vs cathode was used 
        else: # if anode is in gm use anode 
            loc4roi.append(anode_loc[0]) # roi location detail 
            ch_label4roi.append(anode) # ch label used for roi
            ch_type4roi.append('anode') # whether anode vs cathode was used 
            
    roi_reref_labels_all_subj[subj_id] = {'subj_id':[subj_id]*len(reref_ch_names),
                                          'reref_ch_names':reref_ch_names,
                                          'loc4roi':loc4roi,
                                          'ch_label4roi':ch_label4roi,
                                         'ch_type4roi':ch_type4roi }
    roi_reref_labels_master.append(pd.DataFrame({'subj_id':[subj_id]*len(reref_ch_names),
                                          'reref_ch_names':reref_ch_names,
                                          'ch_label4roi':ch_label4roi,
                                         'ch_type4roi':ch_type4roi,
                                                 'loc4roi':loc4roi }))
  

 
roi_reref_labels_master_df = pd.concat(roi_reref_labels_master).reset_index()

# %%
unknown_subj
# Out:
# {'MS009': 1, 'MS015': 1, 'MS022': 1, 'MS024': 1}

# %%
# add hemisphere to df by taking first letter of channel used for localization
roi_reref_labels_master_df['hemi'] = pd.Series(roi_reref_labels_master_df.ch_label4roi.str[0])
# np.unique(roi_reref_labels_master_df.hemi) #MS004 has a probe that starts with p - replace with second letter of label
roi_reref_labels_master_df.hemi.loc[roi_reref_labels_master_df.index[roi_reref_labels_master_df.hemi=='p']] = roi_reref_labels_master_df.loc[roi_reref_labels_master_df.index[roi_reref_labels_master_df.hemi=='p']].ch_label4roi.str[1]
# np.unique(roi_reref_labels_master_df.hemi)
roi_reref_labels_master_df = roi_reref_labels_master_df.drop(columns=['index']) # clean df remove old index column
roi_reref_labels_master_df
# Out:
#      subj_id   reref_ch_names ch_label4roi ch_type4roi  \
# 0      MS002    lacas1-lacas2       lacas1       anode
# 1      MS002    lacas2-lacas3       lacas2       anode
# 2      MS002    lacas3-lacas4       lacas3       anode
# 3      MS002    lacas4-lacas5       lacas4       anode
# 4      MS002    lacas5-lacas6       lacas5       anode
# ...      ...              ...          ...         ...
# 1343   MS041    rmolf4-rmolf5       rmolf4       anode
# 1344   MS041   rmolf9-rmolf10      rmolf10     cathode
# 1345   MS041  rmolf10-rmolf11      rmolf10       anode
# 1346   MS041  rppvnh1-rppvnh2      rppvnh1       anode
# 1347   MS041  rppvnh6-rppvnh7      rppvnh7     cathode
#
#                                  loc4roi hemi
# 0                 left cingulate gyrus d    l
# 1                 left cingulate gyrus e    l
# 2                 left cingulate gyrus f    l
# 3                 left cingulate gyrus f    l
# 4                 left cingulate gyrus g    l
# ...                                  ...  ...
# 1343           right frontal orbital 2 c    r
# 1344  right anterior pars triangularis a    r
# 1345  right anterior pars triangularis a    r
# 1346                       right caudate    r
# 1347      right middle frontal gyrus 7 b    r
#
# [1348 rows x 6 columns]

# %%
(roi_reref_labels_master_df.loc4roi.unique().tolist())
# Out:
# ['left cingulate gyrus d',
#  'left cingulate gyrus e',
#  'left cingulate gyrus f',
#  'left cingulate gyrus g',
#  'left superior frontal gyrus 1 a',
#  'left superior frontal gyrus 2 b',
#  'left superior frontal gyrus 2 c',
#  'left amygdala inferior',
#  'left superior middle temporal gyrus a',
#  'left middle short insular gyrus c',
#  'left anterior short insular gyrus b',
#  'left anterior short insular gyrus a',
#  'left pars opercularis c',
#  'left superior frontal gyrus 4 d',
#  'left hippocampus pes',
#  'left hippocampus body',
#  'left superior middle temporal gyrus d',
#  'left inferior middle temporal gyrus d',
#  'left frontal orbital 4 d',
#  'left middle pars triangularis a',
#  'left posterior pars triangularis a',
#  'left frontal orbital 3 b',
#  'left anterior pars triangularis b',
#  'left posterior long insular gyrus b',
#  'left anterior long insular gyrus a',
#  'left middle frontal gyrus 7 a',
#  'left superior frontal gyrus 5 d',
#  'left pars opercularis a',
#  'left anterior motor b',
#  'left posterior motor i',
#  'right cingulate gyrus d',
#  'right superior frontal gyrus 2 a',
#  'right superior frontal gyrus 3 d',
#  'right amygdala superior',
#  'right superior middle temporal gyrus a',
#  'right anterior short insular gyrus c',
#  'right anterior short insular gyrus b',
#  'right pars opercularis c',
#  'right middle frontal gyrus 5 a',
#  'right hippocampus pes',
#  'right superior middle temporal gyrus c',
#  'right inferior middle temporal gyrus d',
#  'right frontal orbital 4 c',
#  'right frontal orbital 4 d',
#  'right pars orbitalis c',
#  'right middle pars triangularis b',
#  'left frontal pole 4 a',
#  'left superior frontal gyrus 1 b',
#  'left inferior middle temporal gyrus a',
#  'left middle frontal gyrus 4 b',
#  'left superior frontal gyrus 5 a',
#  'left superior frontal gyrus 6 d',
#  'left frontal orbital 4 c',
#  'left pars orbitalis b',
#  'left posterior short insular gyrus a',
#  'right frontal pole 1 c',
#  'right cingulate gyrus e',
#  'right cingulate gyrus f',
#  'right superior frontal gyrus 1 a',
#  'right superior frontal gyrus 2 c',
#  'right middle short insular gyrus c',
#  'right middle short insular gyrus b',
#  'right middle short insular gyrus a',
#  'right middle frontal gyrus 5 b',
#  'right middle frontal gyrus 6 a',
#  'right cingulate gyrus i',
#  'right superior frontal gyrus 4 a',
#  'right superior frontal gyrus 5 d',
#  'right posterior short insular gyrus a',
#  'right somatosensory m',
#  'left superior frontal gyrus 3 d',
#  'left middle frontal gyrus 4 c',
#  'left cingulate gyrus n inferior',
#  'right superior frontal gyrus 3 a',
#  'right superior frontal gyrus 3 c',
#  'right supramarginal gyrus 1 d',
#  'right cingulate gyrus k',
#  'right superior frontal gyrus 6 a',
#  'right middle frontal gyrus 4 b',
#  'left cingulate gyrus c',
#  'left parahippocampal gyrus a',
#  'left middle short insular gyrus b',
#  'left middle frontal gyrus 5 a',
#  'wm',
#  'left superior middle temporal gyrus b',
#  'left cingulate gyrus i',
#  'left superior frontal gyrus 4 a',
#  'gm',
#  'left frontal orbital 3 a',
#  'left frontal orbital 3 c',
#  'left frontal orbital 3 d',
#  'left supramarginal gyrus 4 a',
#  'left superior temporal gyrus c',
#  'left anterior long insular gyrus b',
#  'left somatosensory m',
#  'left posterior motor h',
#  'left middle frontal gyrus 7 b',
#  'left medial occipitotemporal gyrus d',
#  'left inferior middle temporal gyrus e',
#  'left middle frontal gyrus 2 a',
#  'left superior temporal gyrus a',
#  'left amygdala superior',
#  'left superior temporal gyrus d',
#  'left cingulate gyrus k',
#  'left superior frontal gyrus 7 e',
#  'left frontal orbital 4 a',
#  'left anterior pars triangularis a',
#  'left superior middle temporal gyrus c',
#  'right parahippocampal gyrus b',
#  'right inferior temporal pole c',
#  'right basal inferior temporal gyrus b',
#  'right posterior motor k',
#  'right frontal orbital 3 c',
#  'right frontal orbital 3 d',
#  'right middle pars triangularis a',
#  'right inferior middle temporal gyrus f',
#  'left superior frontal gyrus 5 c',
#  'left frontal orbital 4 b',
#  'right superior temporal gyrus b',
#  'right superior middle temporal gyrus b',
#  'right superior frontal gyrus 5 a',
#  'right middle frontal gyrus 4 a',
#  'right superior frontal gyrus 4 d',
#  'unknown',
#  'right middle frontal gyrus 7 a',
#  'right posterior motor h',
#  'left inferior middle temporal gyrus c',
#  'left superior parietal 3 f',
#  'left superior parietal 2 d',
#  'left supramarginal gyrus 3 a',
#  'left cingulate gyrus j',
#  'left superior parietal 1 g',
#  'left somatosensory f',
#  'left frontal orbital 2 b',
#  'left frontal orbital 2 c',
#  'right cingulate gyrus c',
#  'right middle frontal gyrus 2 a',
#  'right amygdala inferior',
#  'right medial occipitotemporal gyrus a',
#  'left middle frontal gyrus 6 a',
#  'left posterior motor k',
#  'left anterior motor d',
#  'left frontal orbital 2 d',
#  'left frontal pole 1 h',
#  'left frontal pole 3 f',
#  'left supramarginal gyrus 5 e',
#  'left superior temporal gyrus g',
#  'left superior temporal gyrus e',
#  'left supramarginal gyrus 1 b',
#  'left superior middle temporal pole b',
#  'left inferior middle temporal pole c',
#  'left superior middle temporal pole d',
#  'left superior frontal gyrus 1 d',
#  'left superior frontal gyrus 6 a',
#  'left superior frontal gyrus 6 c',
#  'left superior angular gyrus b',
#  'left cingulate gyrus o',
#  'right frontal pole 4 a',
#  'right inferior middle temporal gyrus b',
#  'right superior temporal gyrus d',
#  'right anterior pars triangularis b',
#  'right anterior long insular gyrus a',
#  'right superior angular gyrus b',
#  'right cingulate gyrus o',
#  'right superior parietal 2 d',
#  'left middle frontal gyrus 2 b',
#  'left inferior middle temporal gyrus b',
#  'left cingulate gyrus l',
#  'left superior frontal gyrus 7 d',
#  'left parahippocampal gyrus b',
#  'left superior temporal gyrus b',
#  'left posterior short insular gyrus c',
#  'left middle short insular gyrus a',
#  'left cingulate gyrus h',
#  'left parahippocampal gyrus f',
#  'left medial occipitotemporal gyrus e',
#  'right middle frontal gyrus 1 a',
#  'right inferior middle temporal gyrus a',
#  'right anterior short insular gyrus a',
#  'right superior frontal gyrus 5 b',
#  'right superior frontal gyrus 5 c',
#  'right hippocampus body',
#  'right superior middle temporal gyrus d',
#  'right cingulate gyrus j',
#  'right frontal orbital 3 a',
#  'right anterior pars triangularis a',
#  'right medial occipitotemporal gyrus e',
#  'right superior middle temporal gyrus f',
#  'left thalamus',
#  'left superior temporal gyrus f',
#  'left basal inferior temporal gyrus e',
#  'left lateral inferior temporal gyrus f',
#  'left inferior middle temporal gyrus f',
#  'left parahippocampal gyrus g',
#  'left superior occipital gyrus a',
#  'left inferior occipital gyrus b',
#  'left inferior occipital gyrus c superior',
#  'left inferior middle occipital gyrus e',
#  'right thalamus',
#  'right superior temporal gyrus g',
#  'right supramarginal gyrus 5 e',
#  'right cingulate gyrus h',
#  'right frontal orbital 3 b',
#  'right parahippocampal gyrus g',
#  'right parahippocampal gyrus f',
#  'right inferior occipital gyrus a',
#  'right inferior occipital gyrus b',
#  'left lateral occipitotemporal gyrus a',
#  'left basal inferior temporal gyrus d',
#  'left lateral occipitotemporal gyrus b',
#  'left lateral occipitotemporal gyrus c',
#  'left superior middle occipital gyrus e',
#  'left supramarginal gyrus 1 d',
#  'right cingulate gyrus g',
#  'right lateral occipitotemporal gyrus a',
#  'right medial occipitotemporal gyrus d',
#  'right inferior middle occipital gyrus k',
#  'right inferior angular gyrus a',
#  'right superior parietal 1 g',
#  'right frontal orbital 4 a',
#  'right pars orbitalis b',
#  'left pars orbitalis a',
#  'left posterior short insular gyrus b',
#  'left superior parietal 1 f',
#  'left inferior temporal pole b',
#  'right posterior short insular gyrus c',
#  'right posterior short insular gyrus b',
#  'right anterior long insular gyrus b',
#  'right supramarginal gyrus 1 e',
#  'right superior temporal gyrus c',
#  'left superior frontal gyrus 4 b',
#  'left superior frontal gyrus 4 c',
#  'left frontal orbital 5 b',
#  'right superior frontal gyrus 4 c',
#  'right frontal orbital 5 a',
#  'right frontal orbital 5 c',
#  'left frontal pole 1 b',
#  'left posterior pars triangularis b',
#  'left middle frontal gyrus 4 a',
#  'left middle frontal gyrus 3 b',
#  'left frontal orbital 2 a',
#  'right frontal pole 1 b',
#  'right superior frontal gyrus 1 d',
#  'right posterior pars triangularis b',
#  'right superior temporal gyrus e',
#  'right frontal pole 4 f',
#  'right middle frontal gyrus 1 c',
#  'left supramarginal gyrus 5 d',
#  'left posterior motor j',
#  'left supramarginal gyrus 1 e',
#  'left supramarginal gyrus 3 c',
#  'left superior parietal 4 b',
#  'left superior parietal 4 c',
#  'left superior parietal 2 c',
#  'left cingulate gyrus q',
#  'left inferior angular gyrus b',
#  'left pars opercularis b',
#  'left frontal orbital 5 a',
#  'left cingulate gyrus m',
#  'left middle frontal gyrus 3 a',
#  'left anterior long insular gyrus c',
#  'right superior frontal gyrus 2 d',
#  'right supramarginal gyrus 3 b',
#  'left superior frontal gyrus 2 a',
#  'left superior frontal gyrus 3 c',
#  'left superior frontal gyrus 3 a',
#  'left caudate',
#  'right posterior long insular gyrus c',
#  'right anterior long insular gyrus c',
#  'right caudate',
#  'right middle frontal gyrus 4 c',
#  'right middle frontal gyrus 6 b',
#  'right frontal orbital 2 b',
#  'right frontal orbital 2 c',
#  'right middle frontal gyrus 7 b']

# %%
roi_label_info.Custom[~roi_label_info.Custom.isnull()].unique()
# Out:
# array(['temporal pole', 'temporal', 'sts', 'parietal', 'motor', 'dmpfc',
#        'dlpfc', 'vlpfc', 'ofc', 'vmpfc', 'phg', 'acc', 'mcc', 'pcc',
#        'hpc', 'amy', 'ains', 'pins'], dtype=object)

# %%
yba_roi = roi_label_info.Custom[~roi_label_info.Custom.isnull()].unique().tolist()
all_roi = yba_roi+['caudate','thalamus']
all_roi
# Out:
# ['temporal pole',
#  'temporal',
#  'sts',
#  'parietal',
#  'motor',
#  'dmpfc',
#  'dlpfc',
#  'vlpfc',
#  'ofc',
#  'vmpfc',
#  'phg',
#  'acc',
#  'mcc',
#  'pcc',
#  'hpc',
#  'amy',
#  'ains',
#  'pins',
#  'caudate',
#  'thalamus']

# %%
roi_label_info.Custom[]
# Out:
#   Cell In[16], line 1
#     roi_label_info.Custom[]
#                           ^
# SyntaxError: invalid syntax

# %%
roi_reref_labels_master_df.loc4roi.str.contains('thalamus').iloc[idx]

# %%
#### currently there are a few bad ch with locs listed as 'wm', 'gm', 'unknown' 
bad_rois = ['wm', 'gm', 'unknown','oob'] # no oob but adding just in case 
roi_labels = []

#### add roi to df 
for idx, row in roi_reref_labels_master_df.iterrows():
    loc = row.loc4roi
    if any(loc in x  for x in bad_rois): #pd.Series(row['loc4roi']).isin(bad_rois)[0]
        roi_labels.append(np.nan)
    else: 
        if roi_reref_labels_master_df.loc4roi.str.contains('thalamus').iloc[idx]: 
            roi = 'thalamus'
            roi_labels.append(roi)
        elif roi_reref_labels_master_df.loc4roi.str.contains('caudate').iloc[idx]: 
            roi = 'caudate'
            roi_labels.append(roi)
        elif pd.Series(row['loc4roi'].strip()).isin(roi_label_info['Long.name'])[0]:
            roi = roi_label_info['Custom'][np.where(row['loc4roi'].strip() == roi_label_info['Long.name'])[0]].item() 
            roi_labels.append(roi)
        else: 
            roi_labels.append(np.nan)
    
roi_reref_labels_master_df['roi'] = roi_labels

# %%
#### list of labels without ROIs - either poorly labeled or isn't labeled in our YBA roi key
bad_ch_df = roi_reref_labels_master_df[roi_reref_labels_master_df.roi.isnull()]
bad_ch_df.loc4roi.unique().tolist()
# Out:
# ['left inferior middle temporal gyrus d',
#  'right inferior middle temporal gyrus d',
#  'left inferior middle temporal gyrus a',
#  'right somatosensory m',
#  'right supramarginal gyrus 1 d',
#  'wm',
#  'gm',
#  'left supramarginal gyrus 4 a',
#  'left somatosensory m',
#  'left medial occipitotemporal gyrus d',
#  'left inferior middle temporal gyrus e',
#  'right basal inferior temporal gyrus b',
#  'right inferior middle temporal gyrus f',
#  'unknown',
#  'left inferior middle temporal gyrus c',
#  'left supramarginal gyrus 3 a',
#  'left somatosensory f',
#  'right medial occipitotemporal gyrus a',
#  'left supramarginal gyrus 5 e',
#  'left supramarginal gyrus 1 b',
#  'left superior angular gyrus b',
#  'right inferior middle temporal gyrus b',
#  'right superior angular gyrus b',
#  'left inferior middle temporal gyrus b',
#  'left medial occipitotemporal gyrus e',
#  'right inferior middle temporal gyrus a',
#  'right medial occipitotemporal gyrus e',
#  'left basal inferior temporal gyrus e',
#  'left lateral inferior temporal gyrus f',
#  'left inferior middle temporal gyrus f',
#  'left superior occipital gyrus a',
#  'left inferior occipital gyrus b',
#  'left inferior occipital gyrus c superior',
#  'left inferior middle occipital gyrus e',
#  'right supramarginal gyrus 5 e',
#  'right inferior occipital gyrus a',
#  'right inferior occipital gyrus b',
#  'left lateral occipitotemporal gyrus a',
#  'left basal inferior temporal gyrus d',
#  'left lateral occipitotemporal gyrus b',
#  'left lateral occipitotemporal gyrus c',
#  'left superior middle occipital gyrus e',
#  'left supramarginal gyrus 1 d',
#  'right lateral occipitotemporal gyrus a',
#  'right medial occipitotemporal gyrus d',
#  'right inferior middle occipital gyrus k',
#  'right inferior angular gyrus a',
#  'right supramarginal gyrus 1 e',
#  'left supramarginal gyrus 5 d',
#  'left supramarginal gyrus 1 e',
#  'left supramarginal gyrus 3 c',
#  'left inferior angular gyrus b',
#  'right supramarginal gyrus 3 b']

# %%
roi_reref_labels_master_df
# Out:
#      subj_id   reref_ch_names ch_label4roi ch_type4roi  \
# 0      MS002    lacas1-lacas2       lacas1       anode
# 1      MS002    lacas2-lacas3       lacas2       anode
# 2      MS002    lacas3-lacas4       lacas3       anode
# 3      MS002    lacas4-lacas5       lacas4       anode
# 4      MS002    lacas5-lacas6       lacas5       anode
# ...      ...              ...          ...         ...
# 1343   MS041    rmolf4-rmolf5       rmolf4       anode
# 1344   MS041   rmolf9-rmolf10      rmolf10     cathode
# 1345   MS041  rmolf10-rmolf11      rmolf10       anode
# 1346   MS041  rppvnh1-rppvnh2      rppvnh1       anode
# 1347   MS041  rppvnh6-rppvnh7      rppvnh7     cathode
#
#                                  loc4roi hemi      roi
# 0                 left cingulate gyrus d    l      acc
# 1                 left cingulate gyrus e    l      acc
# 2                 left cingulate gyrus f    l      acc
# 3                 left cingulate gyrus f    l      acc
# 4                 left cingulate gyrus g    l      acc
# ...                                  ...  ...      ...
# 1343           right frontal orbital 2 c    r      ofc
# 1344  right anterior pars triangularis a    r    vlpfc
# 1345  right anterior pars triangularis a    r    vlpfc
# 1346                       right caudate    r  caudate
# 1347      right middle frontal gyrus 7 b    r    dlpfc
#
# [1348 rows x 7 columns]

# %%
roi_reref_labels_master_df.to_csv(f'{base_dir}ephys_analysis/subj_info/roi_reref_labels_master_{date}.csv')

# %%
roi_reref_labels_master_df['roi'].value_counts()
# Out:
# dmpfc            179
# acc              155
# ofc              142
# sts              101
# dlpfc             88
# amy               79
# hpc               78
# temporal          74
# vlpfc             70
# ains              50
# pins              46
# thalamus          36
# mcc               28
# parietal          22
# phg               19
# motor             17
# vmpfc             17
# temporal pole     12
# caudate            3
# pcc                1
# Name: roi, dtype: int64

# %%
counts_all_subj = roi_reref_labels_master_df.groupby('subj_id')['roi'].value_counts()

roi_subj_counts = []

for subj_id in subj_ids:
    subj_roi_nums = counts_all_subj[subj_id]
    count_df = pd.DataFrame()
    count_df['subj_id'] = [subj_id]*len(subj_roi_nums.to_list())
    count_df['roi'] = subj_roi_nums.index.tolist()
    count_df['count'] = subj_roi_nums.to_list()
    roi_subj_counts.append(count_df)

roi_subj_counts = pd.concat(roi_subj_counts)

# %%
roi_subj_counts.to_csv(f'{base_dir}ephys_analysis/subj_info/roi_subj_counts_{date}.csv')

# %% [markdown]
# # Check anat by BDI

# %%
bdi_list = pd.read_excel(f'{base_dir}ephys_analysis/subj_info/SWB_subjects.xlsx', sheet_name='Usable_Subjects', usecols=[3])
bdi_list = list(bdi_list.SWB_BDI)
# list(zip(subj_ids,bdi_list))
subj_info_df = pd.DataFrame({'subj_id':subj_ids,'bdi':bdi_list})
subj_info_df
# Out:
#    subj_id  bdi
# 0    MS002   14
# 1    MS003    8
# 2    MS004    7
# 3    MS009   16
# 4    MS011   13
# 5    MS015   26
# 6    MS016   10
# 7    MS017   26
# 8    MS019   12
# 9    MS022   10
# 10   MS024   16
# 11   MS025   10
# 12   MS026    9
# 13   MS027   22
# 14   MS028   13
# 15   MS029   32
# 16   MS030   19
# 17   MS033   39
# 18   MS035   15
# 19   MS041   10

# %%
high_bdi_subj = subj_info_df.subj_id[subj_info_df.bdi>=20]
low_bdi_subj = subj_info_df.subj_id[subj_info_df.bdi<20]

# %%
high_bdi_roi

low_bdi_roi

# %%
roi_subj_counts.roi.unique()
# Out:
# array(['vlpfc', 'dmpfc', 'sts', 'ofc', 'acc', 'ains', 'dlpfc', 'hpc',
#        'amy', 'pins', 'motor', 'vmpfc', 'mcc', 'phg', 'temporal',
#        'temporal pole', 'parietal', 'thalamus', 'pcc', 'caudate'],
#       dtype=object)

# %%
roi_counts_by_bdi = []

for region in roi_subj_counts.roi.unique().tolist():
#     high_bdi_info = roi_subj_counts[roi_subj_counts.subj_id.isin(high_bdi_subj)]
#     low_bdi_info = roi_subj_counts[roi_subj_counts.subj_id.isin(low_bdi_subj)]
    high_bdi_num = np.sum(roi_subj_counts['count'][(roi_subj_counts.subj_id.isin(high_bdi_subj))
                                                   &(roi_subj_counts.roi==region)].values)
    low_bdi_num = np.sum(roi_subj_counts['count'][(roi_subj_counts.subj_id.isin(low_bdi_subj))
                                                  &(roi_subj_counts.roi==region)].values)
    region_bdi_counts = pd.DataFrame({'roi':region,'high_bdi_num':high_bdi_num,'low_bdi_num':low_bdi_num},index=[0])
    roi_counts_by_bdi.append(region_bdi_counts)
    
roi_counts_by_bdi = pd.concat(roi_counts_by_bdi)
roi_counts_by_bdi
# Out:
#              roi  high_bdi_num  low_bdi_num
# 0          vlpfc            13           57
# 0          dmpfc            43          136
# 0            sts             8           93
# 0            ofc            37          105
# 0            acc            34          121
# 0           ains            11           39
# 0          dlpfc            18           70
# 0            hpc            22           56
# 0            amy            19           60
# 0           pins            18           28
# 0          motor             4           13
# 0          vmpfc             7           10
# 0            mcc             5           23
# 0            phg             3           16
# 0       temporal            36           38
# 0  temporal pole            10            2
# 0       parietal             5           17
# 0       thalamus             5           31
# 0            pcc             0            1
# 0        caudate             0            3

# %%
roi_counts_by_bdi.to_csv(f'{base_dir}ephys_analysis/subj_info/roi_counts_by_bdi_{date}.csv')
