# %% [markdown]
# # MS004 Preprocess
# 06/13/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/scripts/saez_python_pipeline/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
# Specify root directory for un-archived data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/'
anat_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/anat_recons/recon_labels/'
neural_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/data/'
behav_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/behavior_analysis/behavior_preprocessed/'

subj_id = 'MS004'
subj_format = ['edf']
subj_site = ['MSSM']

# %% [markdown]
# ### Import Data

# %%
edf_files = glob(f'{neural_dir}/MS004/raw/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)

# %%
mne_data
# Out:
# <RawEDF | MS004_SWB.edf, 148 x 2366080 (2310.6 s), ~2.61 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'aLespM1',
#  'aLespM2',
#  'aLespM3',
#  'aLespM4',
#  'aLespM5',
#  'aLespM6',
#  'aLespM7',
#  'aLespM8',
#  'LespM1',
#  'LespM2',
#  'LespM3',
#  'LespM4',
#  'LespM5',
#  'LespM6',
#  'LespM7',
#  'LespM8',
#  'LespM9',
#  'LespM10',
#  'pLesHM1',
#  'pLesHM2',
#  'pLesHM3',
#  'pLesHM4',
#  'pLesHM5',
#  'pLesHM6',
#  'pLesHM7',
#  'pLesHM8',
#  'LlespM1',
#  'LlespM2',
#  'LlespM3',
#  'LlespM4',
#  'LlespM5',
#  'LlespM6',
#  'RLes21',
#  'RLes22',
#  'RLes23',
#  'RLes24',
#  'RLes25',
#  'RLes26',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'LHplT10',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RHplT10',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'FP2',
#  'F8',
#  'T4',
#  'T6',
#  '02',
#  'F4',
#  'C4',
#  'P4',
#  'FZ',
#  'CZ',
#  'PZ',
#  'EKG1',
#  'EKG2',
#  'C126',
#  'C127',
#  'C128',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %%
# Sanity check one channel data
plt.plot(mne_data._data[3,:4999])
plt.title("Raw iEEG, electrode 0, samples 0-4999")
plt.show()

# %% [markdown]
# ### Examine photodiode

# %%
# Sanity check the photodiode
trig_ix = mne_data.ch_names.index("DC1")
plt.plot(mne_data._data[trig_ix])
plt.title("Photodiode")
plt.show()

# %% [markdown]
# ### Import Anat Recon Info - check all elecs are present in data + recon sheet

# %% [markdown]
# ### Fix edf channel names

# %%
# Load the electrode localization data
ms004_anat_file = glob(f'{anat_dir}/MS004_labels.csv')[0]
elec_locs = pd.read_csv(ms004_anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]

elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0    aLespM1     A23c_L -10.199563  -1.399935  34.199994 -10.271708
# 1    aLespM2     A23c_L -11.799496  -0.199985  38.999994 -11.964828
# 2    aLespM3    Unknown -13.399429   0.599981  43.399993 -13.606759
# 3    aLespM4    Unknown -14.999362   1.799931  48.199993 -15.345050
# 4    aLespM5     A6dl_L -16.599296   2.999881  52.999993 -17.126064
# ..       ...        ...        ...        ...        ...        ...
# 97    RmOlF5    Unknown  25.398950  35.798516  15.799995  28.472357
# 98    RmOlF6    Unknown  28.998799  35.798516  18.999995  32.166475
# 99    RmOlF7   A9/46v_R  32.998632  34.998549  21.399995  36.411860
# 100   RmOlF8     A8vl_R  36.998465  34.998549  24.199995  40.586243
# 101   RmOlF9     A8vl_R  40.598314  34.598566  26.999994  44.285109
#
#          mni_y      mni_z     gm                                  NMM  \
# 0   -13.669751  40.042763   Gray     Left MCgG middle cingulate gyrus
# 1   -11.853191  45.469596  White  Left SMC supplementary motor cortex
# 2   -10.518773  50.487989  White           Left Cerebral White Matter
# 3    -8.725402  55.914290  White           Left Cerebral White Matter
# 4    -6.877599  61.362621  White      Left SFG superior frontal gyrus
# ..         ...        ...    ...                                  ...
# 97   25.071580  17.516928  White          Right Cerebral White Matter
# 98   25.487460  21.130085  White          Right Cerebral White Matter
# 99   24.897113  24.029039   Gray       Right MFG middle frontal gyrus
# 100  25.242135  27.382506   Gray       Right MFG middle frontal gyrus
# 101  25.171395  30.762863   Gray          Right Cerebral White Matter
#
#         Anat                   AnatMacro    BN246  \
# 0    Unknown                       L MCC     L CG
# 1    Unknown                       L MCC     L CG
# 2    Unknown                       L MCC  Unknown
# 3    Unknown                     Unknown  Unknown
# 4    Unknown  L Posterior-Medial Frontal    L SFG
# ..       ...                         ...      ...
# 97   Unknown                     Unknown  Unknown
# 98   Unknown      R Middle Frontal Gyrus  Unknown
# 99   Unknown      R IFG (p Triangularis)    R MFG
# 100  Unknown      R IFG (p Triangularis)    R MFG
# 101  Unknown      R IFG (p Triangularis)    R MFG
#
#                                YBA_1        Manual Examination   Notes
# 0             Left cingulate gyrus L                        WM  lesion
# 1    Left superior frontal gyrus 7 A                        WM  lesion
# 2                            Unknown                        WM  lesion
# 3                            Unknown                        WM  lesion
# 4                            Unknown                    lesion  lesion
# ..                               ...                       ...     ...
# 97                           Unknown                        WM     NaN
# 98                           Unknown                        WM     NaN
# 99    Right middle frontal gyrus 4 B                       NaN     NaN
# 100                          Unknown  Right middle frontal 4 B     NaN
# 101   Right middle frontal gyrus 4 C                       NaN     NaN
#
# [102 rows x 16 columns]

# %%
list(elec_locs.label) #og file includes electrodes that were added after swb was ran
# Out:
# ['aLespM1',
#  'aLespM2',
#  'aLespM3',
#  'aLespM4',
#  'aLespM5',
#  'aLespM6',
#  'aLespM7',
#  'aLespM8',
#  'LaCaS1',
#  'LaCaS10',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LlespM1',
#  'LlespM10',
#  'LlespM2',
#  'LlespM3',
#  'LlespM4',
#  'LlespM5',
#  'LlespM6',
#  'LlespM7',
#  'LlespM8',
#  'LlespM9',
#  'LHplT1',
#  'LHplT10',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'uLmOlF',
#  'LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'pLesHM1',
#  'pLesHM2',
#  'pLesHM3',
#  'pLesHM4',
#  'pLesHM5',
#  'pLesHM6',
#  'pLesHM7',
#  'pLesHM8',
#  'RaCaS1',
#  'RaCaS10',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RHplT1',
#  'RHplT10',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RLes21',
#  'RLes22',
#  'RLes23',
#  'RLes24',
#  'RLes25',
#  'RLes26',
#  'RLes27',
#  'RLes28',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'uRmOlF',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9']

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}

# %%
new_name_dict
# Out:
# {'LmOlF1': 'lmolf1',
#  'LmOlF2': 'lmolf2',
#  'LmOlF3': 'lmolf3',
#  'LmOlF4': 'lmolf4',
#  'LmOlF5': 'lmolf5',
#  'LmOlF6': 'lmolf6',
#  'LmOlF7': 'lmolf7',
#  'LmOlF8': 'lmolf8',
#  'LmOlF9': 'lmolf9',
#  'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'aLespM1': 'alespm1',
#  'aLespM2': 'alespm2',
#  'aLespM3': 'alespm3',
#  'aLespM4': 'alespm4',
#  'aLespM5': 'alespm5',
#  'aLespM6': 'alespm6',
#  'aLespM7': 'alespm7',
#  'aLespM8': 'alespm8',
#  'LespM1': 'lespm1',
#  'LespM2': 'lespm2',
#  'LespM3': 'lespm3',
#  'LespM4': 'lespm4',
#  'LespM5': 'lespm5',
#  'LespM6': 'lespm6',
#  'LespM7': 'llespm7',
#  'LespM8': 'llespm8',
#  'LespM9': 'llespm9',
#  'LespM10': 'llespm10',
#  'pLesHM1': 'pleshm1',
#  'pLesHM2': 'pleshm2',
#  'pLesHM3': 'pleshm3',
#  'pLesHM4': 'pleshm4',
#  'pLesHM5': 'pleshm5',
#  'pLesHM6': 'pleshm6',
#  'pLesHM7': 'pleshm7',
#  'pLesHM8': 'pleshm8',
#  'LlespM1': 'llespm1',
#  'LlespM2': 'llespm2',
#  'LlespM3': 'llespm3',
#  'LlespM4': 'llespm4',
#  'LlespM5': 'llespm5',
#  'LlespM6': 'llespm6',
#  'RLes21': 'rles21',
#  'RLes22': 'rles22',
#  'RLes23': 'rles23',
#  'RLes24': 'rles24',
#  'RLes25': 'rles25',
#  'RLes26': 'rles26',
#  'LHplT1': 'lhplt1',
#  'LHplT2': 'lhplt2',
#  'LHplT3': 'lhplt3',
#  'LHplT4': 'lhplt4',
#  'LHplT5': 'lhplt5',
#  'LHplT6': 'lhplt6',
#  'LHplT7': 'lhplt7',
#  'LHplT8': 'lhplt8',
#  'LHplT9': 'lhplt9',
#  'LHplT10': 'lhplt10',
#  'RHplT1': 'rhplt1',
#  'RHplT2': 'rhplt2',
#  'RHplT3': 'rhplt3',
#  'RHplT4': 'rhplt4',
#  'RHplT5': 'rhplt5',
#  'RHplT6': 'rhplt6',
#  'RHplT7': 'rhplt7',
#  'RHplT8': 'rhplt8',
#  'RHplT9': 'rhplt9',
#  'RHplT10': 'rhplt10',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'FP2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  '02': '02',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'FZ': 'fz',
#  'CZ': 'cz',
#  'PZ': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C126': 'c126',
#  'C127': 'c127',
#  'C128': 'c128',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Rename the mne data according to the localization data
# ----> 2 mne_data.rename_channels(new_name_dict)
#
# File <decorator-gen-43>:12, in rename_channels(self, mapping, allow_duplicates, verbose)
#
# File ~/opt/anaconda3/envs/swb_ephys/lib/python3.10/site-packages/mne/channels/channels.py:414, in SetChannelsMixin.rename_channels(self, mapping, allow_duplicates, verbose)
#     411 from ..io import BaseRaw
#     413 ch_names_orig = list(self.info['ch_names'])
# --> 414 rename_channels(self.info, mapping, allow_duplicates)
#     416 # Update self._orig_units for Raw
#     417 if isinstance(self, BaseRaw):
#     418     # whatever mapping was provided, now we can just use a dict
#
# File <decorator-gen-51>:12, in rename_channels(info, mapping, allow_duplicates, verbose)
#
# File ~/opt/anaconda3/envs/swb_ephys/lib/python3.10/site-packages/mne/channels/channels.py:1088, in rename_channels(info, mapping, allow_duplicates, verbose)
#    1086 # first check and assemble clean mappings of index and name
#    1087 if isinstance(mapping, dict):
# -> 1088     _check_dict_keys(mapping, ch_names, key_description="channel name(s)",
#    1089                      valid_key_source="info")
#    1090     new_names = [(ch_names.index(ch_name), new_name)
#    1091                  for ch_name, new_name in mapping.items()]
#    1092 elif callable(mapping):
#
# File ~/opt/anaconda3/envs/swb_ephys/lib/python3.10/site-packages/mne/utils/check.py:723, in _check_dict_keys(mapping, valid_keys, key_description, valid_key_source)
#     720     _is = 'are' if len(missing) > 1 else 'is'
#     721     msg = (f'Invalid {key_description} {missing} {_is} not present in '
#     722            f'{valid_key_source}')
# --> 723     raise ValueError(msg)
#     725 return mapping
#
# ValueError: Invalid channel name(s) {'pLesHM8', 'LHplT6', 'LmOlF2', 'aLespM8', 'T4', 'RHplT9', 'pLesHM7', 'LHplT10', 'TRIG', 'LmOlF8', 'aLespM6', 'RaCaS6', 'LHplT9', 'RmOlF5', 'RmOlF9', 'aLespM5', 'RmOlF2', 'LespM4', 'LaCaS1', 'LaCaS7', 'LespM6', 'RLes21', 'T6', 'LespM5', 'C128', 'F7', 'DC13', 'LaCaS9', 'LespM2', 'LespM7', 'pLesHM4', 'CZ', 'DC7', 'pLesHM6', 'EKG2', 'RaCaS2', 'RLes26', 'RaCaS3', 'LlespM5', 'LaCaS6', 'F4', 'RmCmS3', 'PZ', 'RHplT3', 'RLes25', 'LmOlF9', 'RmCmS8', 'LmOlF7', 'LHplT5', 'LaCaS10', 'RLes24', 'DC11', 'T3', 'LHplT1', 'F8', 'RmOlF6', 'RHplT4', 'RaCaS8', 'DC10', 'P4', 'RmOlF3', 'FP2', 'RHplT1', 'RmCmS2', 'LHplT4', 'LespM10', 'P3', 'DC15', 'LlespM6', 'LmOlF6', 'LmOlF4', 'Pleth', 'DC3', 'C3', 'LaCaS8', 'C127', 'RHplT10', 'LmOlF5', 'PR', 'DC14', 'RmOlF1', 'RaCaS9', 'LmOlF1', 'RmCmS6', 'pLesHM3', 'EKG1', 'O1', 'RmOlF7', 'RmOlF4', 'LespM8', 'aLespM1', 'LespM1', 'RaCaS7', 'DC4', 'aLespM4', 'pLesHM1', 'RaCaS4', 'RHplT6', 'LaCaS2', 'RaCaS1', 'DC16', 'RmCmS1', 'aLespM3', 'RmCmS7', 'C126', 'RHplT2', 'pLesHM2', 'F3', 'DC6', 'LespM9', 'LHplT7', 'LaCaS5', 'LlespM4', 'DC1', 'aLespM2', 'RHplT8', 'OSAT', 'LlespM1', 'LespM3', 'DC2', 'RLes23', 'LHplT3', 'RHplT7', 'LlespM2', 'T5', 'LHplT2', 'LaCaS3', 'LlespM3', 'DC8', 'RaCaS5', 'LaCaS4', 'pLesHM5', 'LHplT8', 'RmCmS4', 'aLespM7', 'LmOlF3', 'DC5', 'RaCaS10', 'RmCmS5', 'Fp1', 'DC9', 'C4', 'FZ', 'RHplT5', 'DC12', 'RmOlF8', 'RLes22'} are not present in info

# %%
unmatched_seeg
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) #print extra channels in mne_data.ch_names and make sure none of them are neural channels (will be EEG etc.)
# Out:
# ['lespm1', 'lespm2', 'lespm3', 'lespm4', 'lespm5', 'lespm6', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', '02', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c126', 'c127', 'c128', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 45 left & 43 right sEEG electrodes
# We have a total of 88 sEEG electrodes

# %%
list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1'])) #list of non seeg/photodiode channels
# Out:
# ['c3',
#  'dc13',
#  'pleshm6',
#  'pleshm3',
#  'p4',
#  'pleshm8',
#  't6',
#  'p3',
#  'ekg2',
#  'alespm5',
#  'fp1',
#  'o1',
#  'fp2',
#  '02',
#  'pr',
#  'dc9',
#  't4',
#  'alespm6',
#  'cz',
#  'f4',
#  'alespm3',
#  'pleshm5',
#  'alespm7',
#  'dc4',
#  't3',
#  'dc6',
#  'alespm1',
#  'alespm8',
#  'pz',
#  'pleshm4',
#  'pleshm2',
#  'c128',
#  'dc7',
#  'trig',
#  'pleth',
#  'dc3',
#  'alespm4',
#  'dc8',
#  'f7',
#  'alespm2',
#  'f8',
#  'dc15',
#  'pleshm7',
#  'dc10',
#  'dc5',
#  'c126',
#  'ekg1',
#  'c127',
#  't5',
#  'f3',
#  'c4',
#  'dc16',
#  'pleshm1',
#  'dc14',
#  'dc12',
#  'dc2',
#  'osat',
#  'fz',
#  'dc11']

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1']))
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs + 1 (photodiode)
# Out:
# <RawEDF | MS004_SWB.edf, 89 x 2366080 (2310.6 s), ~1.57 GB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
trig_mapping_dict = {'dc1':'stim'} #'stim test1-ref' 'Stim TEST1-REF' stim stands for stimulus 
mne_data.set_channel_types(sEEG_mapping_dict)
mne_data.set_channel_types(trig_mapping_dict)
# Out:
# <RawEDF | MS004_SWB.edf, 89 x 2366080 (2310.6 s), ~1.57 GB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS004_SWB.edf, 89 x 2366080 (2310.6 s), ~1.57 GB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:    4.3s finished
# <RawEDF | MS004_SWB.edf, 89 x 2366080 (2310.6 s), ~1.57 GB, data loaded>

# %% [markdown]
# ### Save out photodiode data
# Note: this is after filtering out line noise

# %%
mne_data.save(f'{neural_dir}/MS004/photodiode.fif', picks='dc1', overwrite=True)

# %% [markdown]
# ### Detect bad channels - detect_bad_elecs function auto detects, then we validate manually

# %%
#make_mne function auto-detects bad electrodes. I want to compare auto vs manual ictal detection

bads = lfp_preprocess_utils.detect_bad_elecs(mne_data, sEEG_mapping_dict)
mne_data.info['bads'] = bads

#resampling this patient is not necessary 
# resample_sr = 500
# mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)

# %%
bads
# Out:
# ['lacas1', 'lacas2', 'lespm1', 'llespm8', 'llespm9', 'rmcms5', 'rmcms6']

# %%
ch_names = list(elec_locs.label.str.lower())
pattern = '[0-9]'
ch_names_no_num = [re.sub(pattern, '', i) for i in ch_names]
probe_names = np.unique(ch_names_no_num)

# %%
probe_names
# Out:
# array(['alespm', 'lacas', 'lhplt', 'llespm', 'lmolf', 'pleshm', 'racas',
#        'rhplt', 'rles', 'rmcms', 'rmolf', 'ulmolf', 'urmolf'], dtype='<U6')

# %%
probe_ch_counts = {} #need this to select channel number for visualization
for p in probe_names:
    c = ch_names_no_num.count(p)
    probe_ch_counts[p] = c

# %%
probe_ch_counts
# Out:
# {'alespm': 8,
#  'lacas': 10,
#  'lhplt': 10,
#  'llespm': 10,
#  'lmolf': 9,
#  'pleshm': 8,
#  'racas': 10,
#  'rhplt': 10,
#  'rles': 8,
#  'rmcms': 8,
#  'rmolf': 9,
#  'ulmolf': 1,
#  'urmolf': 1}

# %%
# %matplotlib notebook 
fig = mne_data.plot(start=0, duration=500, n_channels=10, scalings=mne_data._data.max()/20)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="500">

# %%
# %matplotlib notebook
fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/20)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="500">

# %%
mne_data.info['bads']
# Out:
# ['lmolf8',
#  'rmolf1',
#  'rmolf6',
#  'rmolf7',
#  'lacas1',
#  'lacas5',
#  'lacas11',
#  'lmcms3',
#  'lhplt1',
#  'lhplt2',
#  'lhplt3',
#  'lhplt4',
#  'lhplt5',
#  'lhplt6',
#  'lhplt7',
#  'lhplt8',
#  'lhplt9',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rsifo7',
#  'rsifo8']

# %%
#set bad channel info 
ms003_bad_ch = ['lmolf8',
 'rmolf1',
 'rmolf6',
 'rmolf7',
 'lacas1',
 'lacas5',
 'lacas11',
 'lmcms3',
 'lhplt1',
 'lhplt2',
 'lhplt3',
 'lhplt4',
 'lhplt5',
 'lhplt6',
 'lhplt7',
 'lhplt8',
 'lhplt9',
 'rhplt1',
 'rhplt2',
 'rhplt3',
 'rhplt4',
 'rhplt5',
 'rhplt6',
 'rhplt7',
 'rhplt8',
 'rsifo7',
 'rsifo8']

# %%
len(ms003_bad_ch)
# Out:
# 27

# %%
#manually set bads because doing it in the plot is too buggy
mne_data.info['bads'] = ms003_bad_ch

# %%
mne_data.info #sanity check that bads info saved
# Out:
# <Info | 10 non-empty values
#  bads: 27 items (lmolf8, rmolf1, rmolf6, rmolf7, lacas1, lacas5, ...)
#  ch_names: lmolf1, lmolf2, lmolf3, lmolf4, lmolf5, lmolf6, lmolf7, lmolf8, ...
#  chs: 142 sEEG
#  custom_ref_applied: False
#  dig: 142 items (142 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 256.0 Hz
#  meas_date: 2001-01-01 10:06:23 UTC
#  nchan: 142
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
mne_data.info['bads'] #more sanity checking
# Out:
# ['lmolf8',
#  'rmolf1',
#  'rmolf6',
#  'rmolf7',
#  'lacas1',
#  'lacas5',
#  'lacas11',
#  'lmcms3',
#  'lhplt1',
#  'lhplt2',
#  'lhplt3',
#  'lhplt4',
#  'lhplt5',
#  'lhplt6',
#  'lhplt7',
#  'lhplt8',
#  'lhplt9',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rsifo7',
#  'rsifo8']

# %% [markdown]
# ### Rereference data to wm electrodes

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.wm_ref(mne_data=mne_data, 
                                                                                elec_path=ms003_anat_file, 
                                                                                unmatched_seeg = unmatched_seeg,
                                                                                bad_channels=mne_data.info['bads'],
                                                                                      site = 'MSSM')

# %%
oob_channels
# Out:
# ['lacas11',
#  'lacas12',
#  'laglt10',
#  'laimm12',
#  'lmcms10',
#  'lmolf9',
#  'lsifo8',
#  'racas12',
#  'raglt10',
#  'raimm14',
#  'rmcms10',
#  'rsifo8']

# %%
#need to distinguish between wm channels and oob channels 

#add oob channels to bad channels list
ms003_bad_ch = ms003_bad_ch + oob_channels
ms003_bad_ch = list(np.unique(ms003_bad_ch))
mne_data.info['bads'] = ms003_bad_ch

# %%
mne_data.info['bads'] #needed to rerun plotting function to find this again?
# Out:
# ['lacas1',
#  'lacas11',
#  'lacas12',
#  'lacas5',
#  'laglt10',
#  'laimm12',
#  'lhplt1',
#  'lhplt2',
#  'lhplt3',
#  'lhplt4',
#  'lhplt5',
#  'lhplt6',
#  'lhplt7',
#  'lhplt8',
#  'lhplt9',
#  'lmcms10',
#  'lmcms3',
#  'lmolf8',
#  'lmolf9',
#  'lsifo8',
#  'racas12',
#  'raglt10',
#  'raimm14',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rmcms10',
#  'rmolf1',
#  'rmolf6',
#  'rmolf7',
#  'rsifo7',
#  'rsifo8']

# %%
mne_data_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_reref
# Out:
# <RawEDF | MS003_SWB.edf, 110 x 1281024 (2502.0 s), ~1.05 GB, data loaded>

# %% [markdown]
# ### Save cleaned continuous data

# %%
mne_data.save(f'{neural_dir}/MS003/lfp_data.fif',overwrite=True)

# %%
mne_data_reref.save(f'{neural_dir}/MS002/wm_ref_ieeg.fif',overwrite=True)
