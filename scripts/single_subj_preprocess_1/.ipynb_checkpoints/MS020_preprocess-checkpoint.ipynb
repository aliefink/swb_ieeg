# %% [markdown]
# # MS020 Preprocess
# 06/18/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/scripts/saez_python_pipeline/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
# Specify root directory for un-archived data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/'
anat_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/anat_recons/recon_labels/'
neural_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/data/'
behav_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/behavior_analysis/behavior_preprocessed/'

subj_id = 'MS020'
subj_format = ['edf']
subj_site = ['MSSM']

# %% [markdown]
# ### Import Data

# %%
edf_files = glob(f'{neural_dir}/MS020/raw/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)

# %%
mne_data
# Out:
# <RawEDF | MS020_SWB.edf, 276 x 3306048 (3228.6 s), ~6.80 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOIF1',
#  'LmOIF2',
#  'LmOIF3',
#  'LmOIF4',
#  'LmOIF5',
#  'LmOIF6',
#  'LmOIF7',
#  'LmOIF8',
#  'LmOIF9',
#  'RmOIF1',
#  'RmOIF2',
#  'RmOIF3',
#  'RmOIF4',
#  'RmOIF5',
#  'RmOIF6',
#  'RmOIF7',
#  'RmOIF8',
#  'RmOIF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS13',
#  'RaCaS14',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'LaLIT1',
#  'LaLIT2',
#  'LaLIT3',
#  'LaLIT4',
#  'LaLIT5',
#  'LaLIT6',
#  'LaLIT7',
#  'LaLIT8',
#  'LAgIT1',
#  'LAgIT2',
#  'LAgIT3',
#  'LAgIT4',
#  'LAgIT5',
#  'LAgIT6',
#  'LAgIT7',
#  'LAgIT8',
#  'LAgIT9',
#  'RAgIT1',
#  'RAgIT2',
#  'RAgIT3',
#  'RAgIT4',
#  'RAgIT5',
#  'RAgIT6',
#  'RAgIT7',
#  'RAgIT8',
#  'RAgIT9',
#  'LHpIT1',
#  'LHpIT2',
#  'LHpIT3',
#  'LHpIT4',
#  'LHpIT5',
#  'LHpIT6',
#  'LHpIT7',
#  'LHpIT8',
#  'LHpIT9',
#  'LHpIT10',
#  'RHpIT1',
#  'RHpIT2',
#  'RHpIT3',
#  'RHpIT4',
#  'RHpIT5',
#  'RHpIT6',
#  'RHpIT7',
#  'RHpIT8',
#  'RHpIT9',
#  'RHpIT10',
#  'LaImF1',
#  'LaImF2',
#  'LaImF3',
#  'LaImF4',
#  'LaImF5',
#  'LaImF6',
#  'LaImF7',
#  'LaImF8',
#  'LaImF9',
#  'LaImF10',
#  'LaImF11',
#  'LaImF12',
#  'LaImF13',
#  'LaImF14',
#  'C125',
#  'C126',
#  'C127',
#  'C128',
#  'RaImF1',
#  'RaImF2',
#  'RaImF3',
#  'RaImF4',
#  'RaImF5',
#  'RaImF6',
#  'RaImF7',
#  'RaImF8',
#  'RaImF9',
#  'RaImF10',
#  'RaImF11',
#  'RaImF12',
#  'RaImF13',
#  'RaImF14',
#  'RaImF15',
#  'RaImF16',
#  'FP1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'FP2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'FZ',
#  'CZ',
#  'PZ',
#  'EKG1',
#  'EKG2',
#  'C166',
#  'C167',
#  'C168',
#  'C169',
#  'C170',
#  'C171',
#  'C172',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %%
# Sanity check one channel data
plt.plot(mne_data._data[0,:4999])
plt.title("Raw iEEG, electrode 0, samples 0-4999")
plt.show()

# %% [markdown]
# ### Examine photodiode

# %%
# Sanity check the photodiode
trig_ix = mne_data.ch_names.index("DC1")
plt.plot(mne_data._data[trig_ix])
plt.title("Photodiode")
plt.show()

# %% [markdown]
# ### Import Anat Recon Info - check all elecs are present in data + recon sheet

# %% [markdown]
# ### Fix edf channel names

# %%
# Load the electrode localization data
ms020_anat_file = glob(f'{anat_dir}/MS020_labels.csv')[0]
elec_locs = pd.read_csv(ms020_anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]

elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCaS1    A32sg_L  -4.345531  38.931609   2.348619  -4.366555
# 1    LaCaS10      A9l_L -13.125783  44.927898  45.904190 -15.823208
# 2    LaCaS11      A9l_L -13.923987  45.327651  50.699299 -16.731668
# 3    LaCaS12    Unknown -15.121294  46.127156  56.293593 -18.020168
# 4     LaCaS2    A32sg_L  -5.542839  39.731114   7.143727  -5.882562
# ..       ...        ...        ...        ...        ...        ...
# 139   RmOlF9      IFS_R  40.753032  44.927898  15.135575  47.286859
# 140   uLAgIT     A38m_L -22.704239  20.942741 -16.831817 -23.780532
# 141   uLmOlF     A11m_L  -5.941941  42.929135  -9.639154  -5.742138
# 142   uRAgIT    rHipp_R  14.013176  10.948926 -17.631001  17.531295
# 143   uRmOlF      A13_R   4.434720  44.128393  -6.442414   6.185729
#
#          mni_y      mni_z       gm  \
# 0    31.312979  -9.076791     Gray
# 1    44.034192  42.094287     Gray
# 2    45.244361  47.722366     Gray
# 3    46.918970  54.080927  Unknown
# 4    33.113344  -3.397774     Gray
# ..         ...        ...      ...
# 139  40.810345   5.732863     Gray
# 140   7.255775 -28.784219     Gray
# 141  33.076356 -24.452764     Gray
# 142  -3.865333 -26.684077     Gray
# 143  35.219619 -20.909610    White
#
#                                                    NMM               Anat  \
# 0                   Left ACgG anterior cingulate gyrus           Area s24
# 1                      Left SFG superior frontal gyrus            Unknown
# 2                      Left SFG superior frontal gyrus            Unknown
# 3                                              Unknown            Unknown
# 4                   Left ACgG anterior cingulate gyrus            Area 33
# ..                                                 ...                ...
# 139  Right TrIFG triangular part of the inferior fr...            Unknown
# 140                             Left TMP temporal pole            Unknown
# 141                              Left GRe gyrus rectus           Area Fo1
# 142                    Right PHG parahippocampal gyrus  Entorhinal Cortex
# 143                    Right MFC medial frontal cortex           Area Fo1
#
#                     AnatMacro    BN246                               YBA_1  \
# 0                       L ACC     L CG              Left cingulate gyrus D
# 1    L Superior Frontal Gyrus    L SFG     Left superior frontal gyrus 2 C
# 2    L Superior Frontal Gyrus    L SFG     Left superior frontal gyrus 3 D
# 3                     Unknown  Unknown                             Unknown
# 4                       L ACC     L CG              Left cingulate gyrus D
# ..                        ...      ...                                 ...
# 139    R IFG (p Triangularis)    R IFG  Right anterior pars triangularis A
# 140           L Temporal Pole    L STG       Left superior temporal pole A
# 141            L Rectal Gyrus    L OrG            Left frontal orbital 4 A
# 142   R ParaHippocampal Gyrus   R Hipp       Right parahippocampal gyrus A
# 143            R Rectal Gyrus    R OrG           Right frontal orbital 4 A
#
#                Manual Examination       Notes
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             OOB  borderline
# 3                             OOB         NaN
# 4                              WM         NaN
# ..                            ...         ...
# 139                            WM         NaN
# 140  Left parahippocampal gyrus A         NaN
# 141                           NaN         NaN
# 142                           NaN         NaN
# 143                            WM         NaN
#
# [144 rows x 16 columns]

# %%
list(elec_locs.label)
# Out:
# ['LaCaS1',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LAgIT1',
#  'LAgIT2',
#  'LAgIT3',
#  'LAgIT4',
#  'LAgIT5',
#  'LAgIT6',
#  'LAgIT7',
#  'LAgIT8',
#  'LAgIT9',
#  'LaLIT1',
#  'LaLIT2',
#  'LaLIT3',
#  'LaLIT4',
#  'LaLIT5',
#  'LaLIT6',
#  'LaLIT7',
#  'LaLIT8',
#  'LaLmF1',
#  'LaLmF10',
#  'LaLmF11',
#  'LaLmF12',
#  'LaLmF13',
#  'LaLmF14',
#  'LaLmF2',
#  'LaLmF3',
#  'LaLmF4',
#  'LaLmF5',
#  'LaLmF6',
#  'LaLmF7',
#  'LaLmF8',
#  'LaLmF9',
#  'RHpIT1',
#  'RHpIT10',
#  'RHpIT2',
#  'RHpIT3',
#  'RHpIT4',
#  'RHpIT5',
#  'RHpIT6',
#  'RHpIT7',
#  'RHpIT8',
#  'RHpIT9',
#  'LmCmS1',
#  'LmCmS10',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RaCaS1',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS13',
#  'RaCaS14',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RAgIT1',
#  'RAgIT2',
#  'RAgIT3',
#  'RAgIT4',
#  'RAgIT5',
#  'RAgIT6',
#  'RAgIT7',
#  'RAgIT8',
#  'RAgIT9',
#  'RaLmF1',
#  'RaLmF10',
#  'RaLmF11',
#  'RaLmF12',
#  'RaLmF13',
#  'RaLmF14',
#  'RaLmF15',
#  'RaLmF16',
#  'RaLmF2',
#  'RaLmF3',
#  'RaLmF4',
#  'RaLmF5',
#  'RaLmF6',
#  'RaLmF7',
#  'RaLmF8',
#  'RaLmF9',
#  'LHpIT1',
#  'LHpIT10',
#  'LHpIT2',
#  'LHpIT3',
#  'LHpIT4',
#  'LHpIT5',
#  'LHpIT6',
#  'LHpIT7',
#  'LHpIT8',
#  'LHpIT9',
#  'RmCmS1',
#  'RmCmS10',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'uLAgIT',
#  'uLmOlF',
#  'uRAgIT',
#  'uRmOlF']

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)

# %%
unmatched_names
# Out:
# ['urmolf', 'uragit', 'ulmolf', 'ulagit']

# %%
unmatched_seeg  #make sure there are no unmatched names
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}

# %%
new_name_dict
# Out:
# {'LmOIF1': 'lmolf1',
#  'LmOIF2': 'lmolf2',
#  'LmOIF3': 'lmolf3',
#  'LmOIF4': 'lmolf4',
#  'LmOIF5': 'lmolf5',
#  'LmOIF6': 'lmolf6',
#  'LmOIF7': 'lmolf7',
#  'LmOIF8': 'lmolf8',
#  'LmOIF9': 'lmolf9',
#  'RmOIF1': 'rmolf1',
#  'RmOIF2': 'rmolf2',
#  'RmOIF3': 'rmolf3',
#  'RmOIF4': 'rmolf4',
#  'RmOIF5': 'rmolf5',
#  'RmOIF6': 'rmolf6',
#  'RmOIF7': 'rmolf7',
#  'RmOIF8': 'rmolf8',
#  'RmOIF9': 'rmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'RaCaS13': 'racas13',
#  'RaCaS14': 'racas14',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'LmCmS9': 'lmcms9',
#  'LmCmS10': 'lmcms10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'RmCmS9': 'rmcms9',
#  'RmCmS10': 'rmcms10',
#  'LaLIT1': 'lalit1',
#  'LaLIT2': 'lalit2',
#  'LaLIT3': 'lalit3',
#  'LaLIT4': 'lalit4',
#  'LaLIT5': 'lalit5',
#  'LaLIT6': 'lalit6',
#  'LaLIT7': 'lalit7',
#  'LaLIT8': 'lalit8',
#  'LAgIT1': 'lagit1',
#  'LAgIT2': 'lagit2',
#  'LAgIT3': 'lagit3',
#  'LAgIT4': 'lagit4',
#  'LAgIT5': 'lagit5',
#  'LAgIT6': 'lagit6',
#  'LAgIT7': 'lagit7',
#  'LAgIT8': 'lagit8',
#  'LAgIT9': 'lagit9',
#  'RAgIT1': 'ragit1',
#  'RAgIT2': 'ragit2',
#  'RAgIT3': 'ragit3',
#  'RAgIT4': 'ragit4',
#  'RAgIT5': 'ragit5',
#  'RAgIT6': 'ragit6',
#  'RAgIT7': 'ragit7',
#  'RAgIT8': 'ragit8',
#  'RAgIT9': 'ragit9',
#  'LHpIT1': 'lhpit1',
#  'LHpIT2': 'lhpit2',
#  'LHpIT3': 'lhpit3',
#  'LHpIT4': 'lhpit4',
#  'LHpIT5': 'lhpit5',
#  'LHpIT6': 'lhpit6',
#  'LHpIT7': 'lhpit7',
#  'LHpIT8': 'lhpit8',
#  'LHpIT9': 'lhpit9',
#  'LHpIT10': 'lhpit10',
#  'RHpIT1': 'rhpit1',
#  'RHpIT2': 'rhpit2',
#  'RHpIT3': 'rhpit3',
#  'RHpIT4': 'rhpit4',
#  'RHpIT5': 'rhpit5',
#  'RHpIT6': 'rhpit6',
#  'RHpIT7': 'rhpit7',
#  'RHpIT8': 'rhpit8',
#  'RHpIT9': 'rhpit9',
#  'RHpIT10': 'rhpit10',
#  'LaImF1': 'lalmf1',
#  'LaImF2': 'lalmf2',
#  'LaImF3': 'lalmf3',
#  'LaImF4': 'lalmf4',
#  'LaImF5': 'lalmf5',
#  'LaImF6': 'lalmf6',
#  'LaImF7': 'lalmf7',
#  'LaImF8': 'lalmf8',
#  'LaImF9': 'lalmf9',
#  'LaImF10': 'lalmf10',
#  'LaImF11': 'lalmf11',
#  'LaImF12': 'lalmf12',
#  'LaImF13': 'lalmf13',
#  'LaImF14': 'lalmf14',
#  'C125': 'c125',
#  'C126': 'c126',
#  'C127': 'c127',
#  'C128': 'c128',
#  'RaImF1': 'ralmf1',
#  'RaImF2': 'ralmf2',
#  'RaImF3': 'ralmf3',
#  'RaImF4': 'ralmf4',
#  'RaImF5': 'ralmf5',
#  'RaImF6': 'ralmf6',
#  'RaImF7': 'ralmf7',
#  'RaImF8': 'ralmf8',
#  'RaImF9': 'ralmf9',
#  'RaImF10': 'ralmf10',
#  'RaImF11': 'ralmf11',
#  'RaImF12': 'ralmf12',
#  'RaImF13': 'ralmf13',
#  'RaImF14': 'ralmf14',
#  'RaImF15': 'ralmf15',
#  'RaImF16': 'ralmf16',
#  'FP1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'FP2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'FZ': 'fz',
#  'CZ': 'cz',
#  'PZ': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C166': 'c166',
#  'C167': 'c167',
#  'C168': 'c168',
#  'C169': 'c169',
#  'C170': 'c170',
#  'C171': 'c171',
#  'C172': 'c172',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS020_SWB.edf, 276 x 3306048 (3228.6 s), ~6.80 GB, data loaded>

# %%
unmatched_seeg
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) #print extra channels in mne_data.ch_names and make sure none of them are neural channels (will be EEG etc.)
# Out:
# ['c125', 'c126', 'c127', 'c128', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c166', 'c167', 'c168', 'c169', 'c170', 'c171', 'c172', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 72 left & 68 right sEEG electrodes
# We have a total of 140 sEEG electrodes

# %%
list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1'])) #list of non seeg/photodiode channels
# Out:
# ['o2',
#  'c227',
#  'c176',
#  'c4',
#  'c242',
#  'c128',
#  'dc2',
#  'dc4',
#  'c168',
#  'pz',
#  'c189',
#  'c228',
#  'c198',
#  'c214',
#  'o1',
#  'ekg1',
#  'c230',
#  'c177',
#  'c229',
#  't6',
#  'c179',
#  'c238',
#  'fp1',
#  'c180',
#  'c201',
#  'c196',
#  'c254',
#  'c205',
#  'c248',
#  'c197',
#  'c186',
#  'c178',
#  'c194',
#  'c249',
#  'dc10',
#  'c174',
#  'c183',
#  'c253',
#  'p3',
#  'c173',
#  'pleth',
#  't3',
#  'c246',
#  'dc8',
#  'c237',
#  'c187',
#  'c184',
#  'dc11',
#  'dc6',
#  'pr',
#  'f3',
#  'c167',
#  'c171',
#  'dc13',
#  'c199',
#  't5',
#  'c223',
#  'c212',
#  'c232',
#  'c204',
#  't4',
#  'c172',
#  'c191',
#  'cz',
#  'c209',
#  'c251',
#  'c240',
#  'c224',
#  'c217',
#  'c126',
#  'c182',
#  'c206',
#  'f8',
#  'c3',
#  'c231',
#  'c192',
#  'p4',
#  'dc14',
#  'c235',
#  'dc9',
#  'c190',
#  'dc12',
#  'c239',
#  'c236',
#  'c200',
#  'dc7',
#  'c213',
#  'c195',
#  'c219',
#  'c127',
#  'c175',
#  'ekg2',
#  'dc5',
#  'c193',
#  'c215',
#  'f7',
#  'c241',
#  'c244',
#  'fp2',
#  'c169',
#  'dc15',
#  'c210',
#  'c250',
#  'c181',
#  'trig',
#  'c255',
#  'c243',
#  'fz',
#  'c225',
#  'dc16',
#  'c220',
#  'c208',
#  'c247',
#  'c222',
#  'c185',
#  'c211',
#  'c221',
#  'c256',
#  'f4',
#  'c170',
#  'c226',
#  'c218',
#  'c125',
#  'c245',
#  'osat',
#  'c216',
#  'c233',
#  'c202',
#  'c188',
#  'c207',
#  'c252',
#  'c234',
#  'c203',
#  'c166',
#  'dc3']

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1']))
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs + 1 (photodiode)
# Out:
# <RawEDF | MS020_SWB.edf, 141 x 3306048 (3228.6 s), ~3.47 GB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
trig_mapping_dict = {'dc1':'stim'} #stim stands for stimulus
mne_data.set_channel_types(sEEG_mapping_dict)
mne_data.set_channel_types(trig_mapping_dict)
# Out:
# <RawEDF | MS020_SWB.edf, 141 x 3306048 (3228.6 s), ~3.47 GB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS020_SWB.edf, 141 x 3306048 (3228.6 s), ~3.47 GB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 140 out of 140 | elapsed:   11.4s finished
# <RawEDF | MS020_SWB.edf, 141 x 3306048 (3228.6 s), ~3.47 GB, data loaded>

# %% [markdown]
# ### Resampling Data

# %%
#resampling if patient is not sampled at 512
resample_sr = 512
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 141 out of 141 | elapsed:   14.3s finished
# <RawEDF | MS020_SWB.edf, 141 x 1653024 (3228.6 s), ~1.74 GB, data loaded>

# %% [markdown]
# ### Save out photodiode data
# Note: this is after filtering out line noise and resampling

# %%
mne_data.save(f'{neural_dir}/MS020/photodiode.fif', picks='dc1', overwrite=True)

# %% [markdown]
# ### Detect bad channels - detect_bad_elecs function auto detects, then we validate manually

# %%
#make_mne function auto-detects bad electrodes. I want to compare auto vs manual ictal detection

bads = lfp_preprocess_utils.detect_bad_elecs(mne_data, sEEG_mapping_dict) #worked perfectly for this pt besides photodiode
mne_data.info['bads'] = bads

# %%
bads #bads picked up research? - manually remove
#bads = bads[:-1]
#bads
# Out:
# ['lagit4',
#  'lagit5',
#  'lagit7',
#  'lalmf4',
#  'lmcms7',
#  'lmolf5',
#  'lmolf6',
#  'lmolf7',
#  'lmolf8',
#  'lmolf9',
#  'racas13',
#  'ragit5',
#  'ralmf1',
#  'rhpit8']

# %%
mne_data.info['bads'] = bads

# %%
mne_data.info
# Out:
# <Info | 10 non-empty values
#  bads: 14 items (lagit4, lagit5, lagit7, lalmf4, lmcms7, lmolf5, ...)
#  ch_names: lmolf1, lmolf2, lmolf3, lmolf4, lmolf5, lmolf6, lmolf7, lmolf8, ...
#  chs: 140 sEEG
#  custom_ref_applied: False
#  dig: 140 items (140 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 256.0 Hz
#  meas_date: 2001-01-01 13:08:46 UTC
#  nchan: 140
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
ch_names = list(elec_locs.label.str.lower())
pattern = '[0-9]'
ch_names_no_num = [re.sub(pattern, '', i) for i in ch_names]
probe_names = np.unique(ch_names_no_num)

# %%
probe_names
# Out:
# array(['lacas', 'lagit', 'lalit', 'lalmf', 'lhpit', 'lmcms', 'lmolf',
#        'racas', 'ragit', 'ralmf', 'rhpit', 'rmcms', 'rmolf', 'ulagit',
#        'ulmolf', 'uragit', 'urmolf'], dtype='<U6')

# %%
probe_ch_counts = {} #need this to select channel number for visualization
for p in probe_names:
    c = ch_names_no_num.count(p)
    probe_ch_counts[p] = c

# %%
probe_ch_counts
# Out:
# {'lacas': 12,
#  'lagit': 9,
#  'lalit': 8,
#  'lalmf': 14,
#  'lhpit': 10,
#  'lmcms': 10,
#  'lmolf': 9,
#  'racas': 14,
#  'ragit': 9,
#  'ralmf': 16,
#  'rhpit': 10,
#  'rmcms': 10,
#  'rmolf': 9,
#  'ulagit': 1,
#  'ulmolf': 1,
#  'uragit': 1,
#  'urmolf': 1}

# %%
# %matplotlib notebook 
fig = mne_data.plot(start=0, duration=500, n_channels=10, scalings=mne_data._data.max()/20)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="800.0000211927631">
# <img src="data:image/png;base64,..." width="500.00001324547696">

# %%
mne_data.info['bads']
# Out:
# ['lpioc14',
#  'lpioc2',
#  'lpioc3',
#  'riito5',
#  'riito6',
#  'riito7',
#  'rmoif1',
#  'rsppc5',
#  'rsppc7',
#  'rsppc8']

# %%
# %matplotlib notebook
fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/20)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="800.0000211927631">
# <img src="data:image/png;base64,..." width="500.00001324547696">

# %%
mne_data.info['bads']
# Out:
# ['lpioc14',
#  'lpioc2',
#  'lpioc3',
#  'riito5',
#  'riito6',
#  'riito7',
#  'rmoif1',
#  'rsppc5',
#  'rsppc7',
#  'rsppc8']

# %%
#set bad channel info 
ms020_bad_ch = ['lagit4','lagit5','lagit7','lalmf4','lmcms7','lmolf5','lmolf6','lmolf7','lmolf8','lmolf9','racas13','ragit5','ralmf1','rhpit8']

# %%
len(ms019_bad_ch)
# Out:
# 4

# %%
#manually set bads because doing it in the plot is too buggy
mne_data.info['bads'] = ms019_bad_ch

# %%
mne_data.info #sanity check that bads info saved
# Out:
# <Info | 10 non-empty values
#  bads: 4 items (ragit9, lsppc11, lsppc12, rsppc12)
#  ch_names: lmoif1, lmoif2, lmoif3, lmoif4, lmoif5, lmoif6, lmoif7, lmoif8, ...
#  chs: 170 sEEG
#  custom_ref_applied: False
#  dig: 170 items (170 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 256.0 Hz
#  meas_date: 2001-01-01 10:46:21 UTC
#  nchan: 170
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
mne_data.info['bads'] #more sanity checking
# Out:
# ['ragit9', 'lsppc11', 'lsppc12', 'rsppc12']

# %% [markdown]
# ### Rereference data to wm electrodes

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.wm_ref(mne_data=mne_data, 
                                                                                elec_path=ms019_anat_file, 
                                                                                unmatched_seeg = unmatched_seeg,
                                                                                bad_channels=mne_data.info['bads'],
                                                                                      site = 'MSSM')

# %%
oob_channels
# Out:
# ['lacas11',
#  'lacas12',
#  'lhpit10',
#  'liito2',
#  'liito7',
#  'liito8',
#  'lmcms10',
#  'lmcms8',
#  'lmcms9',
#  'lsppc11',
#  'lsppc12',
#  'racas11',
#  'racas12',
#  'ragit10',
#  'rhpit10',
#  'riito7',
#  'riito8',
#  'rmcms10',
#  'rmcms8',
#  'rmcms9',
#  'rpioc14',
#  'rsppc11',
#  'rsppc12']

# %%
#need to distinguish between wm channels and oob channels 

#add oob channels to bad channels list
ms019_bad_ch = ms019_bad_ch + oob_channels
ms019_bad_ch = list(np.unique(ms019_bad_ch))
mne_data.info['bads'] = ms019_bad_ch

# %%
mne_data.info['bads'] #needed to rerun plotting function to find this again?
# Out:
# ['lacas11',
#  'lacas12',
#  'lhpit10',
#  'liito2',
#  'liito7',
#  'liito8',
#  'lmcms10',
#  'lmcms8',
#  'lmcms9',
#  'lsppc11',
#  'lsppc12',
#  'racas11',
#  'racas12',
#  'ragit10',
#  'ragit9',
#  'rhpit10',
#  'riito7',
#  'riito8',
#  'rmcms10',
#  'rmcms8',
#  'rmcms9',
#  'rpioc14',
#  'rsppc11',
#  'rsppc12']

# %%
mne_data_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_reref
# Out:
# <RawEDF | MS019_SWB.edf, 138 x 1088000 (2125.0 s), ~1.12 GB, data loaded>

# %% [markdown]
# ### Save cleaned continuous data

# %%
mne_data.save(f'{neural_dir}/MS019/lfp_data.fif',overwrite=True)

# %%
mne_data_reref.save(f'{neural_dir}/MS019/wm_ref_ieeg.fif',overwrite=True)
