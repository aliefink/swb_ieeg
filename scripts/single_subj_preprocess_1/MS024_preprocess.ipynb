# %% [markdown]
# # MS024 Preprocess
# 06/27/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/scripts/saez_python_pipeline/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
# Specify root directory for un-archived data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/'
anat_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/anat_recons/recon_labels/'
neural_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/ephys_analysis/data/'
behav_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/behavior_analysis/behavior_preprocessed/'

subj_id = 'MS024'
subj_format = ['edf']
subj_site = ['MSSM']

# %% [markdown]
# ### Import Data

# %%
edf_files = glob(f'{neural_dir}{subj_id}/raw/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)

# %%
mne_data
# Out:
# <RawEDF | MS024_SWB2.edf, 276 x 1796032 (1753.9 s), ~3.69 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'C63',
#  'C64',
#  'LAglT1',
#  'LAglT2',
#  'LAglT3',
#  'LAglT4',
#  'LAglT5',
#  'LAglT6',
#  'LAglT7',
#  'LAglT8',
#  'LAglT9',
#  'LAglT10',
#  'LAglT11',
#  'LAglT12',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RAglT10',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'LHplT10',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RHplT10',
#  'RHplT11',
#  'RHplT12',
#  'LpTpT1',
#  'LpTpT2',
#  'LpTpT3',
#  'LpTpT4',
#  'LpTpT5',
#  'LpTpT6',
#  'LpTpT7',
#  'LpTpT8',
#  'LpTpT9',
#  'LpTpT10',
#  'RpTpT1',
#  'RpTpT2',
#  'RpTpT3',
#  'RpTpT4',
#  'RpTpT5',
#  'RpTpT6',
#  'RpTpT7',
#  'RpTpT8',
#  'RpTpT9',
#  'RpTpT10',
#  'LalmM1',
#  'LalmM2',
#  'LalmM3',
#  'LalmM4',
#  'LalmM5',
#  'LalmM6',
#  'LalmM7',
#  'LalmM8',
#  'LalmM9',
#  'LalmM10',
#  'LalmM11',
#  'LalmM12',
#  'LalmM13',
#  'LalmM14',
#  'LalmM15',
#  'LalmM16',
#  'RalmM1',
#  'RalmM2',
#  'RalmM3',
#  'RalmM4',
#  'RalmM5',
#  'RalmM6',
#  'RalmM7',
#  'RalmM8',
#  'RalmM9',
#  'RalmM10',
#  'RalmM11',
#  'RalmM12',
#  'RalmM13',
#  'RalmM14',
#  'RalmM15',
#  'RalmM16',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %%
# Sanity check one channel data
plt.plot(mne_data._data[0,:4999])
plt.title("Raw iEEG, electrode 0, samples 0-4999")
plt.show()

# %% [markdown]
# ### Examine photodiode

# %%
# Sanity check the photodiode
trig_ix = mne_data.ch_names.index("DC1")
plt.plot(mne_data._data[trig_ix])
plt.title("Photodiode")
plt.show()

# %% [markdown]
# ### Import Anat Recon Info - check all elecs are present in data + recon sheet

# %% [markdown]
# ### Fix edf channel names

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]

elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCaS1    A32sg_L  -9.585028  33.547612  -8.399996  -7.341464
# 1     LaCaS2    A24rv_L -10.383780  35.544494  -3.199996  -7.836954
# 2     LaCaS3    A32sg_L -11.182533  37.541376   1.200003  -8.565094
# 3     LaCaS4    A32sg_L -11.981285  39.138881   6.000003  -9.278688
# 4     LaCaS5     A32p_L -12.780038  40.736386  10.000003  -9.959662
# ..       ...        ...        ...        ...        ...        ...
# 153   RpTpT6    Unknown  41.535135 -42.333891   2.000003  47.333236
# 154   RpTpT7    A39rv_R  45.928274 -43.532020   4.400003  51.611318
# 155   RpTpT8    A39rv_R  49.522661 -44.330772   8.000003  55.038627
# 156   RpTpT9    A39rv_R  53.915800 -45.528901  10.000003  59.330250
# 157  RpTpT10    A39rv_R  57.510186 -45.928278  14.000003  62.666209
#
#          mni_y      mni_z     gm                                 NMM  \
# 0    29.783339 -10.461633   Gray  Left ACgG anterior cingulate gyrus
# 1    32.391655  -5.187904   Gray  Left ACgG anterior cingulate gyrus
# 2    34.852447  -0.672995  White          Left Cerebral White Matter
# 3    36.919524   4.361672  White          Left Cerebral White Matter
# 4    38.999035   8.575860   Gray  Left ACgG anterior cingulate gyrus
# ..         ...        ...    ...                                 ...
# 153 -46.351650   3.678801  White         Right Cerebral White Matter
# 154 -47.097978   6.009020   Gray         Right Cerebral White Matter
# 155 -47.328077   9.797899   Gray     Right MTG middle temporal gyrus
# 156 -48.095321  11.780442   Gray     Right MTG middle temporal gyrus
# 157 -47.886575  16.104984   Gray             Right AnG angular gyrus
#
#                Anat                AnatMacro    BN246  \
# 0          Area s32                    L ACC     L CG
# 1          Area s32                    L ACC     L CG
# 2           Unknown                    L ACC     L CG
# 3           Unknown                    L ACC     L CG
# 4           Unknown                    L ACC     L CG
# ..              ...                      ...      ...
# 153         Unknown                  Unknown  Unknown
# 154         Unknown  R Middle Temporal Gyrus    R IPL
# 155         Unknown  R Middle Temporal Gyrus    R IPL
# 156  Area PGa (IPL)  R Middle Temporal Gyrus    R IPL
# 157  Area PGa (IPL)  R Middle Temporal Gyrus    R IPL
#
#                                       YBA_1 Manual Examination  Notes
# 0                    Left cingulate gyrus C                NaN    NaN
# 1                    Left cingulate gyrus D                NaN    NaN
# 2                    Left cingulate gyrus E                NaN    NaN
# 3                                   Unknown                NaN    NaN
# 4                    Left cingulate gyrus F                NaN    NaN
# ..                                      ...                ...    ...
# 153  Right superior middle temporal gyrus F                NaN    NaN
# 154  Right superior middle temporal gyrus F                 WM    NaN
# 155  Right superior middle temporal gyrus F                NaN    NaN
# 156  Right superior middle temporal gyrus F                NaN    NaN
# 157         Right superior temporal gyrus G                NaN    NaN
#
# [158 rows x 16 columns]

# %%
list(elec_locs.label)
# Out:
# ['LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'LAgIT1',
#  'LAgIT2',
#  'LAgIT3',
#  'LAgIT4',
#  'LAgIT5',
#  'LAgIT6',
#  'LAgIT7',
#  'LAgIT8',
#  'LAgIT9',
#  'LAgIT10',
#  'LAgIT11',
#  'LAgIT12',
#  'LaImM1',
#  'LaImM2',
#  'LaImM3',
#  'LaImM4',
#  'LaImM5',
#  'LaImM6',
#  'LaImM7',
#  'LaImM8',
#  'LaImM9',
#  'LaImM10',
#  'LaImM11',
#  'LaImM12',
#  'LaImM13',
#  'LaImM14',
#  'LaImM15',
#  'LaImM16',
#  'LHpIT1',
#  'LHpIT2',
#  'LHpIT3',
#  'LHpIT4',
#  'LHpIT5',
#  'LHpIT6',
#  'LHpIT7',
#  'LHpIT8',
#  'LHpIT9',
#  'LHpIT10',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'LpTpT1',
#  'LpTpT2',
#  'LpTpT3',
#  'LpTpT4',
#  'LpTpT5',
#  'LpTpT6',
#  'LpTpT7',
#  'LpTpT8',
#  'LpTpT9',
#  'LpTpT10',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RAgIT1',
#  'RAgIT2',
#  'RAgIT3',
#  'RAgIT4',
#  'RAgIT5',
#  'RAgIT6',
#  'RAgIT7',
#  'RAgIT8',
#  'RAgIT9',
#  'RAgIT10',
#  'RaImM1',
#  'RaImM2',
#  'RaImM3',
#  'RaImM4',
#  'RaImM5',
#  'RaImM6',
#  'RaImM7',
#  'RaImM8',
#  'RaImM9',
#  'RaImM10',
#  'RaImM11',
#  'RaImM12',
#  'RaImM13',
#  'RaImM14',
#  'RaImM15',
#  'RaImM16',
#  'RHpIT1',
#  'RHpIT2',
#  'RHpIT3',
#  'RHpIT4',
#  'RHpIT5',
#  'RHpIT6',
#  'RHpIT7',
#  'RHpIT8',
#  'RHpIT9',
#  'RHpIT10',
#  'RHpIT11',
#  'RHpIT12',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RpTpT1',
#  'RpTpT2',
#  'RpTpT3',
#  'RpTpT4',
#  'RpTpT5',
#  'RpTpT6',
#  'RpTpT7',
#  'RpTpT8',
#  'RpTpT9',
#  'RpTpT10']

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)

# %%
unmatched_names
# Out:
# []

# %%
unmatched_seeg  #make sure there are no unmatched names
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}

# %%
new_name_dict
# Out:
# {'LmOlF1': 'lmolf1',
#  'LmOlF2': 'lmolf2',
#  'LmOlF3': 'lmolf3',
#  'LmOlF4': 'lmolf4',
#  'LmOlF5': 'lmolf5',
#  'LmOlF6': 'lmolf6',
#  'LmOlF7': 'lmolf7',
#  'LmOlF8': 'lmolf8',
#  'LmOlF9': 'lmolf9',
#  'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'LmCmS9': 'lmcms9',
#  'LmCmS10': 'lmcms10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'RmCmS9': 'rmcms9',
#  'RmCmS10': 'rmcms10',
#  'C63': 'c63',
#  'C64': 'c64',
#  'LAglT1': 'lagit1',
#  'LAglT2': 'lagit2',
#  'LAglT3': 'lagit3',
#  'LAglT4': 'lagit4',
#  'LAglT5': 'lagit5',
#  'LAglT6': 'lagit6',
#  'LAglT7': 'lagit7',
#  'LAglT8': 'lagit8',
#  'LAglT9': 'lagit9',
#  'LAglT10': 'lagit10',
#  'LAglT11': 'lagit11',
#  'LAglT12': 'lagit12',
#  'RAglT1': 'ragit1',
#  'RAglT2': 'ragit2',
#  'RAglT3': 'ragit3',
#  'RAglT4': 'ragit4',
#  'RAglT5': 'ragit5',
#  'RAglT6': 'ragit6',
#  'RAglT7': 'ragit7',
#  'RAglT8': 'ragit8',
#  'RAglT9': 'ragit9',
#  'RAglT10': 'ragit10',
#  'LHplT1': 'lhpit1',
#  'LHplT2': 'lhpit2',
#  'LHplT3': 'lhpit3',
#  'LHplT4': 'lhpit4',
#  'LHplT5': 'lhpit5',
#  'LHplT6': 'lhpit6',
#  'LHplT7': 'lhpit7',
#  'LHplT8': 'lhpit8',
#  'LHplT9': 'lhpit9',
#  'LHplT10': 'lhpit10',
#  'RHplT1': 'rhpit1',
#  'RHplT2': 'rhpit2',
#  'RHplT3': 'rhpit3',
#  'RHplT4': 'rhpit4',
#  'RHplT5': 'rhpit5',
#  'RHplT6': 'rhpit6',
#  'RHplT7': 'rhpit7',
#  'RHplT8': 'rhpit8',
#  'RHplT9': 'rhpit9',
#  'RHplT10': 'rhpit10',
#  'RHplT11': 'rhpit11',
#  'RHplT12': 'rhpit12',
#  'LpTpT1': 'lptpt1',
#  'LpTpT2': 'lptpt2',
#  'LpTpT3': 'lptpt3',
#  'LpTpT4': 'lptpt4',
#  'LpTpT5': 'lptpt5',
#  'LpTpT6': 'lptpt6',
#  'LpTpT7': 'lptpt7',
#  'LpTpT8': 'lptpt8',
#  'LpTpT9': 'lptpt9',
#  'LpTpT10': 'lptpt10',
#  'RpTpT1': 'rptpt1',
#  'RpTpT2': 'rptpt2',
#  'RpTpT3': 'rptpt3',
#  'RpTpT4': 'rptpt4',
#  'RpTpT5': 'rptpt5',
#  'RpTpT6': 'rptpt6',
#  'RpTpT7': 'rptpt7',
#  'RpTpT8': 'rptpt8',
#  'RpTpT9': 'rptpt9',
#  'RpTpT10': 'rptpt10',
#  'LalmM1': 'laimm1',
#  'LalmM2': 'laimm2',
#  'LalmM3': 'laimm3',
#  'LalmM4': 'laimm4',
#  'LalmM5': 'laimm5',
#  'LalmM6': 'laimm6',
#  'LalmM7': 'laimm7',
#  'LalmM8': 'laimm8',
#  'LalmM9': 'laimm9',
#  'LalmM10': 'laimm10',
#  'LalmM11': 'laimm11',
#  'LalmM12': 'laimm12',
#  'LalmM13': 'laimm13',
#  'LalmM14': 'laimm14',
#  'LalmM15': 'laimm15',
#  'LalmM16': 'laimm16',
#  'RalmM1': 'raimm1',
#  'RalmM2': 'raimm2',
#  'RalmM3': 'raimm3',
#  'RalmM4': 'raimm4',
#  'RalmM5': 'raimm5',
#  'RalmM6': 'raimm6',
#  'RalmM7': 'raimm7',
#  'RalmM8': 'raimm8',
#  'RalmM9': 'raimm9',
#  'RalmM10': 'raimm10',
#  'RalmM11': 'raimm11',
#  'RalmM12': 'raimm12',
#  'RalmM13': 'raimm13',
#  'RalmM14': 'raimm14',
#  'RalmM15': 'raimm15',
#  'RalmM16': 'raimm16',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS024_SWB2.edf, 276 x 1796032 (1753.9 s), ~3.69 GB, data loaded>

# %%
unmatched_seeg
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) #print extra channels in mne_data.ch_names and make sure none of them are neural channels (will be EEG etc.)
# Out:
# ['c63', 'c64', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 79 left & 79 right sEEG electrodes
# We have a total of 158 sEEG electrodes

# %%
list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1'])) #list of non seeg/photodiode channels
# Out:
# ['c254',
#  't5',
#  'c252',
#  'c222',
#  'c220',
#  'c216',
#  'c250',
#  'c188',
#  'c229',
#  'c206',
#  'c214',
#  'fz',
#  'c198',
#  'c215',
#  'c256',
#  'dc13',
#  'c249',
#  'c63',
#  'c240',
#  'c233',
#  'c243',
#  'dc14',
#  'o1',
#  'ekg2',
#  'c231',
#  'c227',
#  'p4',
#  'c207',
#  'c199',
#  'c230',
#  'pleth',
#  'c241',
#  'c245',
#  'c3',
#  'ekg1',
#  'c194',
#  'c208',
#  'c190',
#  'c218',
#  'c221',
#  'dc8',
#  'pr',
#  'fp1',
#  't4',
#  'c4',
#  'c225',
#  'dc10',
#  'c255',
#  'dc5',
#  'osat',
#  'c244',
#  'c200',
#  'dc16',
#  'c248',
#  'c236',
#  't3',
#  'c205',
#  'dc15',
#  'pz',
#  'c204',
#  'f7',
#  'c202',
#  'f8',
#  'c237',
#  'c251',
#  'c224',
#  'c201',
#  'c183',
#  'c182',
#  'cz',
#  'c253',
#  'c210',
#  'c247',
#  'c192',
#  'c193',
#  'c212',
#  'dc4',
#  'c228',
#  'c217',
#  'dc11',
#  'c196',
#  'c235',
#  'c232',
#  'c187',
#  'c223',
#  'c239',
#  'c209',
#  'fp2',
#  'c186',
#  'c191',
#  'f3',
#  'c238',
#  'trig',
#  'dc7',
#  'c213',
#  'c203',
#  'c246',
#  'dc2',
#  't6',
#  'dc9',
#  'c197',
#  'c185',
#  'c234',
#  'c189',
#  'c226',
#  'c64',
#  'c211',
#  'f4',
#  'dc3',
#  'p3',
#  'c184',
#  'dc12',
#  'c195',
#  'c219',
#  'dc6',
#  'c242',
#  'o2']

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1']))
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs + 1 (photodiode)
# Out:
# <RawEDF | MS024_SWB2.edf, 159 x 1796032 (1753.9 s), ~2.13 GB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
trig_mapping_dict = {'dc1':'stim'} #stim stands for stimulus
mne_data.set_channel_types(sEEG_mapping_dict)
mne_data.set_channel_types(trig_mapping_dict)
# Out:
# <RawEDF | MS024_SWB2.edf, 159 x 1796032 (1753.9 s), ~2.13 GB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS024_SWB2.edf, 159 x 1796032 (1753.9 s), ~2.13 GB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 158 out of 158 | elapsed:    6.8s finished
# <RawEDF | MS024_SWB2.edf, 159 x 1796032 (1753.9 s), ~2.13 GB, data loaded>

# %% [markdown]
# ### Resampling Data

# %%
#resampling if patient is not sampled at 512
resample_sr = 512
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 159 out of 159 | elapsed:    9.4s finished
# <RawEDF | MS024_SWB2.edf, 159 x 898016 (1753.9 s), ~1.06 GB, data loaded>

# %% [markdown]
# ### Save out photodiode data
# Note: this is after filtering out line noise and resampling

# %%
mne_data.save(f'{neural_dir}{subj_id}/photodiode.fif', picks='dc1', overwrite=True)

# %% [markdown]
# ### Detect bad channels - detect_bad_elecs function auto detects, then we validate manually

# %%
#make_mne function auto-detects bad electrodes. I want to compare auto vs manual ictal detection

bads = lfp_preprocess_utils.detect_bad_elecs(mne_data, sEEG_mapping_dict) #worked perfectly for this pt besides photodiode
mne_data.info['bads'] = bads

# %%
bads #bads picked up research? - manually remove
#bads = bads[:-1]
#bads
# Out:
# ['lagit10',
#  'lagit11',
#  'laimm11',
#  'lhpit8',
#  'lhpit9',
#  'lmcms8',
#  'lmcms9',
#  'lmolf1',
#  'lptpt9',
#  'racas7',
#  'racas8',
#  'racas9',
#  'raimm16',
#  'rmolf8',
#  'rptpt10']

# %%
mne_data.info['bads'] = bads

# %%
mne_data.info
# Out:
# <Info | 10 non-empty values
#  bads: 15 items (lagit10, lagit11, laimm11, lhpit8, lhpit9, lmcms8, ...)
#  ch_names: lmolf1, lmolf2, lmolf3, lmolf4, lmolf5, lmolf6, lmolf7, lmolf8, ...
#  chs: 158 sEEG
#  custom_ref_applied: False
#  dig: 158 items (158 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 256.0 Hz
#  meas_date: 2001-01-01 14:32:49 UTC
#  nchan: 158
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
ch_names = list(elec_locs.label.str.lower())
pattern = '[0-9]'
ch_names_no_num = [re.sub(pattern, '', i) for i in ch_names]
probe_names = np.unique(ch_names_no_num)

# %%
probe_names
# Out:
# array(['lacas', 'lagit', 'laimm', 'lhpit', 'lmcms', 'lmolf', 'lptpt',
#        'racas', 'ragit', 'raimm', 'rhpit', 'rmcms', 'rmolf', 'rptpt'],
#       dtype='<U5')

# %%
probe_ch_counts = {} #need this to select channel number for visualization
for p in probe_names:
    c = ch_names_no_num.count(p)
    probe_ch_counts[p] = c

# %%
probe_ch_counts
# Out:
# {'lacas': 12,
#  'lagit': 12,
#  'laimm': 16,
#  'lhpit': 10,
#  'lmcms': 10,
#  'lmolf': 9,
#  'lptpt': 10,
#  'racas': 12,
#  'ragit': 10,
#  'raimm': 16,
#  'rhpit': 12,
#  'rmcms': 10,
#  'rmolf': 9,
#  'rptpt': 10}

# %%
# %matplotlib notebook 
fig = mne_data.plot(start=0, duration=500, n_channels=10, scalings=mne_data._data.max()/20)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads']
# Out:
# []

# %%
#set bad channel info 
bad_ch = []

# %%
#manually set bads because doing it in the plot is too buggy
mne_data.info['bads'] = bad_ch

# %% [markdown]
# ### Rereference data to wm electrodes

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.wm_ref(mne_data=mne_data, 
                                                                                elec_path=anat_file, 
                                                                                unmatched_seeg = unmatched_seeg,
                                                                                bad_channels=mne_data.info['bads'],
                                                                                      site = 'MSSM')

# %%
oob_channels
# Out:
# ['lacas12',
#  'lagit11',
#  'lagit12',
#  'laimm16',
#  'lmcms7',
#  'lmcms9',
#  'lmcms10',
#  'racas12',
#  'ragit9',
#  'ragit10',
#  'raimm16',
#  'rhpit12',
#  'rmcms9',
#  'rmcms10']

# %%
#need to distinguish between wm channels and oob channels 

#add oob channels to bad channels list
bad_ch = bad_ch + oob_channels
bad_ch = list(np.unique(bad_ch))
mne_data.info['bads'] = bad_ch

# %%
mne_data.info['bads'] #needed to rerun plotting function to find this again?
# Out:
# ['lacas12',
#  'lagit11',
#  'lagit12',
#  'laimm16',
#  'lmcms10',
#  'lmcms7',
#  'lmcms9',
#  'racas12',
#  'ragit10',
#  'ragit9',
#  'raimm16',
#  'rhpit12',
#  'rmcms10',
#  'rmcms9']

# %%
mne_data_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_reref
# Out:
# <RawEDF | MS024_SWB2.edf, 123 x 898016 (1753.9 s), ~842.9 MB, data loaded>

# %% [markdown]
# ### Save cleaned continuous data

# %%
mne_data.save(f'{neural_dir}{subj_id}/lfp_data.fif',overwrite=True)

# %%
mne_data_reref.save(f'{neural_dir}{subj_id}/wm_ref_ieeg.fif',overwrite=True)
