# %% [markdown]
# # MS003 Preprocess
# 10/05/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
# sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')
sys.path.append('/Users/alexandrafink/Documents/GitHub/afink_lfp_pipeline/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS003'
subj_format = ['edf']
subj_site = ['MSSM']

base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/'
anat_dir = f'{base_dir}anat_recons/recon_labels/{subj_id}'
neural_dir = f'{base_dir}ephys_analysis/data/{subj_id}'

# %% [markdown]
# ### Import Data

# %%
edf_files = glob(f'{neural_dir}/raw/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)

# %%
mne_data
# Out:
# <RawEDF | MS003_SWB.edf, 276 x 1281024 (2502.0 s), ~2.63 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'C63',
#  'C64',
#  'LalmM1',
#  'LalmM2',
#  'LalmM3',
#  'LalmM4',
#  'LalmM5',
#  'LalmM6',
#  'LalmM7',
#  'LalmM8',
#  'LalmM9',
#  'LalmM10',
#  'LalmM11',
#  'LalmM12',
#  'RalmM1',
#  'RalmM2',
#  'RalmM3',
#  'RalmM4',
#  'RalmM5',
#  'RalmM6',
#  'RalmM7',
#  'RalmM8',
#  'RalmM9',
#  'RalmM10',
#  'RalmM11',
#  'RalmM12',
#  'RalmM13',
#  'RalmM14',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'LAglT1',
#  'LAglT2',
#  'LAglT3',
#  'LAglT4',
#  'LAglT5',
#  'LAglT6',
#  'LAglT7',
#  'LAglT8',
#  'LAglT9',
#  'LAglT10',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RAglT10',
#  'LslfO1',
#  'LslfO2',
#  'LslfO3',
#  'LslfO4',
#  'LslfO5',
#  'LslfO6',
#  'LslfO7',
#  'LslfO8',
#  'RslfO1',
#  'RslfO2',
#  'RslfO3',
#  'RslfO4',
#  'RslfO5',
#  'RslfO6',
#  'RslfO7',
#  'RslfO8',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C166',
#  'C167',
#  'C168',
#  'C169',
#  'C170',
#  'C171',
#  'C172',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %%
# Sanity check one channel data
plt.plot(mne_data._data[0,:4999])
plt.title("Raw iEEG, electrode 0, samples 0-4999")
plt.show()

# %% [markdown]
# ### Examine photodiode

# %%
# Sanity check the photodiode
trig_ix = mne_data.ch_names.index("DC1")
plt.plot(mne_data._data[trig_ix])
plt.title("Photodiode")
plt.show()

# %% [markdown]
# ### Import Anat Recon Info - check all elecs are present in data + recon sheet

# %% [markdown]
# ### Fix edf channel names

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]

elec_locs
# Out:
#        label     BN246label          x          y          z      mni_x  \
# 0     LaCaS1          A13_L  -3.709764  46.512775 -11.687440  -4.844184
# 1    LaCaS10          A9l_L  -7.308108  68.072344  28.268504  -9.890195
# 2    LaCaS11          A9l_L  -7.308108  70.467851  33.063217  -9.892679
# 3    LaCaS12        Unknown  -7.707924  71.665605  37.458371 -10.273735
# 4     LaCaS2        A32sg_L  -4.109580  48.908282  -7.691846  -5.555517
# ..       ...            ...        ...        ...        ...        ...
# 139   RsifO4  A1/2/3tonIa_R  45.467608   7.785400  15.882161  47.901761
# 140   RsifO5  A1/2/3tonIa_R  50.665217   7.785400  16.281720  53.246638
# 141   RsifO6         A4hf_R  55.463009   7.785400  16.281720  58.186651
# 142   RsifO7   A1/2/3ulhf_R  60.660618   7.386149  16.681280  63.565237
# 143   RsifO8   A1/2/3ulhf_R  66.258042   7.386149  17.080839  69.448794
#
#          mni_y      mni_z       gm                                 NMM  \
# 0    33.999416 -13.071413     Gray  Left ACgG anterior cingulate gyrus
# 1    54.149132  36.376249     Gray     Left SFG superior frontal gyrus
# 2    56.415478  42.253481  Unknown     Left SFG superior frontal gyrus
# 3    57.347304  47.465558  Unknown                             Unknown
# 4    36.209189  -7.914435     Gray  Left ACgG anterior cingulate gyrus
# ..         ...        ...      ...                                 ...
# 139  -5.107676  15.077895     Gray          Right CO central operculum
# 140  -4.702719  15.720999    White         Right Cerebral White Matter
# 141  -4.353392  15.814696    White         Right Cerebral White Matter
# 142  -4.449542  16.441334     Gray         Right PoG postcentral gyrus
# 143  -4.121329  17.083347  Unknown                             Unknown
#
#               Anat                 AnatMacro    BN246  \
# 0         Area s32       L Mid Orbital Gyrus    L OrG
# 1          Unknown  L Superior Frontal Gyrus    L SFG
# 2          Unknown  L Superior Frontal Gyrus    L SFG
# 3          Unknown                   Unknown  Unknown
# 4         Area s32                     L ACC     L CG
# ..             ...                       ...      ...
# 139  Area OP3 [VS]      R Rolandic Operculum    R PoG
# 140        Unknown      R Rolandic Operculum    R PoG
# 141        Unknown      R Rolandic Operculum    R PrG
# 142        Area 3b       R Postcentral Gyrus    R PoG
# 143        Unknown       R Postcentral Gyrus    R PoG
#
#                                YBA_1                ManualExamination Notes
# 0              Left frontal pole 1 B                              NaN   NaN
# 1                            Unknown  Left superior frontal gyrus 1 B   NaN
# 2    Left superior frontal gyrus 2 C                              NaN   NaN
# 3                            Unknown                              OOB   NaN
# 4             Left cingulate gyrus D                              NaN   NaN
# ..                               ...                              ...   ...
# 139            Right somatosensory M                              NaN   NaN
# 140                          Unknown                               WM   NaN
# 141          Right posterior motor J                               WM   NaN
# 142            Right somatosensory L                              NaN   NaN
# 143            Right somatosensory L                              OOB   NaN
#
# [144 rows x 16 columns]

# %%
list(elec_locs.label)
# Out:
# ['LaCaS1',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LAglT1',
#  'LAglT10',
#  'LAglT2',
#  'LAglT3',
#  'LAglT4',
#  'LAglT5',
#  'LAglT6',
#  'LAglT7',
#  'LAglT8',
#  'LAglT9',
#  'LaImM1',
#  'LaImM10',
#  'LaImM11',
#  'LaImM12',
#  'LaImM2',
#  'LaImM3',
#  'LaImM4',
#  'LaImM5',
#  'LaImM6',
#  'LaImM7',
#  'LaImM8',
#  'LaImM9',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'LmCmS1',
#  'LmCmS10',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'uLmOlF',
#  'LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'LsifO1',
#  'LsifO2',
#  'LsifO3',
#  'LsifO4',
#  'LsifO5',
#  'LsifO6',
#  'LsifO7',
#  'LsifO8',
#  'RaCaS1',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RAglT1',
#  'RAglT10',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RaImM1',
#  'RaImM10',
#  'RaImM11',
#  'RaImM12',
#  'RaImM13',
#  'RaImM14',
#  'RaImM2',
#  'RaImM3',
#  'RaImM4',
#  'RaImM5',
#  'RaImM6',
#  'RaImM7',
#  'RaImM8',
#  'RaImM9',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RmCmS1',
#  'RmCmS10',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'uRmOlF',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RsifO1',
#  'RsifO2',
#  'RsifO3',
#  'RsifO4',
#  'RsifO5',
#  'RsifO6',
#  'RsifO7',
#  'RsifO8']

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}

# %%
new_name_dict
# Out:
# {'LmOlF1': 'lmolf1',
#  'LmOlF2': 'lmolf2',
#  'LmOlF3': 'lmolf3',
#  'LmOlF4': 'lmolf4',
#  'LmOlF5': 'lmolf5',
#  'LmOlF6': 'lmolf6',
#  'LmOlF7': 'lmolf7',
#  'LmOlF8': 'lmolf8',
#  'LmOlF9': 'lmolf9',
#  'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'LmCmS9': 'lmcms9',
#  'LmCmS10': 'lmcms10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'RmCmS9': 'rmcms9',
#  'RmCmS10': 'rmcms10',
#  'C63': 'c63',
#  'C64': 'c64',
#  'LalmM1': 'laimm1',
#  'LalmM2': 'laimm2',
#  'LalmM3': 'laimm3',
#  'LalmM4': 'laimm4',
#  'LalmM5': 'laimm5',
#  'LalmM6': 'laimm6',
#  'LalmM7': 'laimm7',
#  'LalmM8': 'laimm8',
#  'LalmM9': 'laimm9',
#  'LalmM10': 'laimm10',
#  'LalmM11': 'laimm11',
#  'LalmM12': 'laimm12',
#  'RalmM1': 'raimm1',
#  'RalmM2': 'raimm2',
#  'RalmM3': 'raimm3',
#  'RalmM4': 'raimm4',
#  'RalmM5': 'raimm5',
#  'RalmM6': 'raimm6',
#  'RalmM7': 'raimm7',
#  'RalmM8': 'raimm8',
#  'RalmM9': 'raimm9',
#  'RalmM10': 'raimm10',
#  'RalmM11': 'raimm11',
#  'RalmM12': 'raimm12',
#  'RalmM13': 'raimm13',
#  'RalmM14': 'raimm14',
#  'LHplT1': 'lhplt1',
#  'LHplT2': 'lhplt2',
#  'LHplT3': 'lhplt3',
#  'LHplT4': 'lhplt4',
#  'LHplT5': 'lhplt5',
#  'LHplT6': 'lhplt6',
#  'LHplT7': 'lhplt7',
#  'LHplT8': 'lhplt8',
#  'LHplT9': 'lhplt9',
#  'RHplT1': 'rhplt1',
#  'RHplT2': 'rhplt2',
#  'RHplT3': 'rhplt3',
#  'RHplT4': 'rhplt4',
#  'RHplT5': 'rhplt5',
#  'RHplT6': 'rhplt6',
#  'RHplT7': 'rhplt7',
#  'RHplT8': 'rhplt8',
#  'RHplT9': 'rhplt9',
#  'LAglT1': 'laglt1',
#  'LAglT2': 'laglt2',
#  'LAglT3': 'laglt3',
#  'LAglT4': 'laglt4',
#  'LAglT5': 'laglt5',
#  'LAglT6': 'laglt6',
#  'LAglT7': 'laglt7',
#  'LAglT8': 'laglt8',
#  'LAglT9': 'laglt9',
#  'LAglT10': 'laglt10',
#  'RAglT1': 'raglt1',
#  'RAglT2': 'raglt2',
#  'RAglT3': 'raglt3',
#  'RAglT4': 'raglt4',
#  'RAglT5': 'raglt5',
#  'RAglT6': 'raglt6',
#  'RAglT7': 'raglt7',
#  'RAglT8': 'raglt8',
#  'RAglT9': 'raglt9',
#  'RAglT10': 'raglt10',
#  'LslfO1': 'lsifo1',
#  'LslfO2': 'lsifo2',
#  'LslfO3': 'lsifo3',
#  'LslfO4': 'lsifo4',
#  'LslfO5': 'lsifo5',
#  'LslfO6': 'lsifo6',
#  'LslfO7': 'lsifo7',
#  'LslfO8': 'lsifo8',
#  'RslfO1': 'rsifo1',
#  'RslfO2': 'rsifo2',
#  'RslfO3': 'rsifo3',
#  'RslfO4': 'rsifo4',
#  'RslfO5': 'rsifo5',
#  'RslfO6': 'rsifo6',
#  'RslfO7': 'rsifo7',
#  'RslfO8': 'rsifo8',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C166': 'c166',
#  'C167': 'c167',
#  'C168': 'c168',
#  'C169': 'c169',
#  'C170': 'c170',
#  'C171': 'c171',
#  'C172': 'c172',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS003_SWB.edf, 276 x 1281024 (2502.0 s), ~2.63 GB, data loaded>

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) #print extra channels in mne_data.ch_names and make sure none of them are neural channels (will be EEG etc.)
# Out:
# ['c63', 'c64', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c166', 'c167', 'c168', 'c169', 'c170', 'c171', 'c172', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 70 left & 72 right sEEG electrodes
# We have a total of 142 sEEG electrodes

# %%
list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1'])) #list of non seeg/photodiode channels
# Out:
# ['c250',
#  'c189',
#  'ekg1',
#  'c199',
#  'c202',
#  'c211',
#  'c228',
#  'c186',
#  'c253',
#  'c256',
#  'c206',
#  'dc2',
#  'c217',
#  'f7',
#  'p4',
#  't4',
#  'pz',
#  'c207',
#  'c243',
#  'c246',
#  'c222',
#  'c191',
#  'c205',
#  'dc14',
#  'dc4',
#  'c3',
#  'c187',
#  'c63',
#  'dc3',
#  'c188',
#  'fz',
#  'c180',
#  'c236',
#  'c169',
#  'c247',
#  'c233',
#  'c244',
#  'c179',
#  'c172',
#  'dc10',
#  'c174',
#  'dc13',
#  'c214',
#  'c239',
#  'osat',
#  'c212',
#  'f8',
#  'c173',
#  'c238',
#  'f4',
#  'c220',
#  'c226',
#  'c182',
#  'c198',
#  'c224',
#  'dc16',
#  'pr',
#  'dc9',
#  'c245',
#  'trig',
#  'fp1',
#  'c225',
#  'c203',
#  'c195',
#  'c176',
#  'o1',
#  'c197',
#  'dc11',
#  't5',
#  'c175',
#  'c249',
#  'c219',
#  'c248',
#  'c181',
#  'c183',
#  'c242',
#  'dc15',
#  'dc7',
#  'c231',
#  'c185',
#  'c230',
#  'ekg2',
#  'c193',
#  'c200',
#  'c234',
#  'p3',
#  'c168',
#  'c227',
#  'c4',
#  'c235',
#  'c208',
#  'c210',
#  'c232',
#  'c254',
#  'c218',
#  't6',
#  'o2',
#  'c194',
#  't3',
#  'c229',
#  'dc5',
#  'dc6',
#  'c209',
#  'c184',
#  'c240',
#  'c167',
#  'c170',
#  'dc12',
#  'c171',
#  'c178',
#  'c196',
#  'c64',
#  'c252',
#  'c215',
#  'fp2',
#  'c213',
#  'c166',
#  'c237',
#  'c190',
#  'c192',
#  'f3',
#  'c177',
#  'c255',
#  'pleth',
#  'c201',
#  'c223',
#  'c216',
#  'c221',
#  'dc8',
#  'c204',
#  'c241',
#  'c251',
#  'cz']

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names+['dc1']))
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs + 1 (photodiode)
# Out:
# <RawEDF | MS003_SWB.edf, 143 x 1281024 (2502.0 s), ~1.36 GB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
trig_mapping_dict = {'dc1':'stim'} #'stim test1-ref' 'Stim TEST1-REF' stim stands for stimulus 
mne_data.set_channel_types(sEEG_mapping_dict)
mne_data.set_channel_types(trig_mapping_dict)
# Out:
# <RawEDF | MS003_SWB.edf, 143 x 1281024 (2502.0 s), ~1.36 GB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS003_SWB.edf, 143 x 1281024 (2502.0 s), ~1.37 GB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 142 out of 142 | elapsed:    3.8s finished
# <RawEDF | MS003_SWB.edf, 143 x 1281024 (2502.0 s), ~1.37 GB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 143 out of 143 | elapsed:    6.9s finished
# <RawEDF | MS003_SWB.edf, 143 x 1251000 (2502.0 s), ~1.33 GB, data loaded>

# %% [markdown]
# ### Save out photodiode data
# Note: this is after filtering out line noise + resampling

# %%
mne_data.save(f'{neural_dir}/photodiode.fif', picks='dc1', overwrite=True)

# %%
mne_data.drop_channels('dc1') #remove from mne data
# Out:
# <RawEDF | MS003_SWB.edf, 142 x 1251000 (2502.0 s), ~1.32 GB, data loaded>

# %% [markdown]
# ### Detect bad channels - detect_bad_elecs function auto detects, then we validate manually

# %%
ch_names = list(elec_locs.label.str.lower())
pattern = '[0-9]'
ch_names_no_num = [re.sub(pattern, '', i) for i in ch_names]
probe_names = np.unique(ch_names_no_num)

# %%
probe_names
# Out:
# array(['lacas', 'laglt', 'laimm', 'lhplt', 'lmcms', 'lmolf', 'lsifo',
#        'racas', 'raglt', 'raimm', 'rhplt', 'rmcms', 'rmolf', 'rsifo',
#        'ulmolf', 'urmolf'], dtype='<U6')

# %%
probe_ch_counts = {} #need this to select channel number for visualization
for p in probe_names:
    c = ch_names_no_num.count(p)
    probe_ch_counts[p] = c

# %%
probe_ch_counts
# Out:
# {'lacas': 12,
#  'laglt': 10,
#  'laimm': 12,
#  'lhplt': 9,
#  'lmcms': 10,
#  'lmolf': 9,
#  'lsifo': 8,
#  'racas': 12,
#  'raglt': 10,
#  'raimm': 14,
#  'rhplt': 9,
#  'rmcms': 10,
#  'rmolf': 9,
#  'rsifo': 8,
#  'ulmolf': 1,
#  'urmolf': 1}

# %%
# %matplotlib notebook 
# %matplotlib notebook 

fig = mne_data.plot(start=0, duration=500, n_channels=20, scalings=mne_data._data.max()/50)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads']
# Out:
# ['lmolf8',
#  'rmolf1',
#  'rmolf6',
#  'rmolf7',
#  'lacas1',
#  'lacas5',
#  'lacas11',
#  'lmcms3',
#  'lhplt1',
#  'lhplt2',
#  'lhplt3',
#  'lhplt4',
#  'lhplt5',
#  'lhplt6',
#  'lhplt7',
#  'lhplt8',
#  'lhplt9',
#  'rhplt2',
#  'rhplt3',
#  'rhplt5',
#  'rhplt4',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rhplt1',
#  'rsifo7',
#  'rsifo8']

# %%
mne_data.info['bads']
# Out:
# ['lmolf8',
#  'rmolf1',
#  'rmolf6',
#  'rmolf7',
#  'lacas1',
#  'lacas5',
#  'lacas11',
#  'lmcms3',
#  'lhplt1',
#  'lhplt2',
#  'lhplt3',
#  'lhplt4',
#  'lhplt5',
#  'lhplt6',
#  'lhplt7',
#  'lhplt8',
#  'lhplt9',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rsifo7',
#  'rsifo8']

# %%
#set bad channel info 
bad_ch = ['lmolf8','rmolf1','rmolf6','rmolf7','lacas1','lacas5','lacas11','lmcms3','lhplt1','lhplt2',
'lhplt3','lhplt4','lhplt5','lhplt6','lhplt7','lhplt8','lhplt9','rhplt1','rhplt2','rhplt3','rhplt4',
          'rhplt5','rhplt6','rhplt7','rhplt8','rsifo7','rsifo8']

# %%
len(bad_ch)
# Out:
# 27

# %%
mne_data.info #sanity check that bads info saved
# Out:
# <Info | 10 non-empty values
#  bads: 27 items (lmolf8, rmolf1, rmolf6, rmolf7, lacas1, lacas5, ...)
#  ch_names: lmolf1, lmolf2, lmolf3, lmolf4, lmolf5, lmolf6, lmolf7, lmolf8, ...
#  chs: 142 sEEG
#  custom_ref_applied: False
#  dig: 142 items (142 EEG)
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 250.0 Hz
#  meas_date: 2001-01-01 10:06:23 UTC
#  nchan: 142
#  projs: []
#  sfreq: 500.0 Hz
# >

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
#define oob elecs as bad before saving out lfp file 
oob_elec = [elec_locs['label'].iloc[ind].lower() for ind, data in elec_locs['ManualExamination'].str.lower().items() if data=='oob']
oob_elec
# Out:
# ['lacas12',
#  'laglt10',
#  'lhplt9',
#  'lmcms10',
#  'lmolf9',
#  'lsifo8',
#  'racas12',
#  'raglt10',
#  'raimm14',
#  'rhplt9',
#  'rmcms10',
#  'rsifo8']

# %%
bad_ch = bad_ch + oob_elec
mne_data.info['bads'] = bad_ch
# mne_data.info['bads']

# %%
mne_data.save(f'{neural_dir}/raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data - Both WM ref and Bipolar ref!### Rereference data to wm electrodes

# %%
# mne_data = mne.io.read_raw_fif(f'{neural_dir}/raw_ieeg.fif')

# %% [markdown]
# ### WM REF

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.wm_ref(mne_data=mne_data, 
                                                                                elec_path=anat_file, 
                                                                                unmatched_seeg = unmatched_seeg,
                                                                                bad_channels=mne_data.info['bads'],
                                                                                      site = 'MSSM')

# %%
mne_data_wm_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_wm_reref
# Out:
# <RawEDF | MS003_SWB.edf, 119 x 1251000 (2502.0 s), ~1.11 GB, data loaded>

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = mne_data_wm_reref.plot(start=0, duration=500, n_channels=50, scalings=mne_data._data.max()/50)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
#to drop unreferenced bad ch - 
#mne_data_wm_reref.drop_channels([x for x in mne_data_reref.ch_names if '-' not in x])

# %% [markdown]
# ### Save wm reref

# %%
mne_data_wm_reref.save(f'{neural_dir}/wm_ref_ieeg.fif',overwrite=True)

# %% [markdown]
# ###  BIPOLAR REF

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.bipolar_ref(elec_path=anat_file, 
                                       bad_channels=mne_data.info['bads'], 
                                       unmatched_seeg=unmatched_seeg,
                                       site='MSSM')

# %%
mne_data_bp_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_bp_reref
# Out:
# <RawEDF | MS003_SWB.edf, 130 x 1251000 (2502.0 s), ~1.21 GB, data loaded>

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = mne_data_bp_reref.plot(start=0, duration=500, n_channels=50, scalings=mne_data._data.max()/50)
fig.fake_keypress('a')
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %% [markdown]
# ### Save bp reref

# %%
mne_data_bp_reref.save(f'{neural_dir}/bp_ref_ieeg.fif',overwrite=True)
